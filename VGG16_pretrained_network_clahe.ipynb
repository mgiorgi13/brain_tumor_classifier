# %% [markdown]
# ## Import Libraries

# %%
#from google.colab import drive
import os
import shutil
import numpy as np
import random as rn
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
import matplotlib.pyplot as plt
from sklearn import metrics
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import LabelBinarizer

from keras.applications import VGG16
from keras.models import Sequential ,load_model
from keras.layers import Dense, Dropout, Flatten

# %% [markdown]
# ## Google Drive connection

# %%
# mount drive 
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## CLAHE UTILITY

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

from tensorflow.keras import backend as K
from itertools import cycle
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, roc_auc_score

dataset_path = "/content/drive/MyDrive/DiDonato_Giorgi"

# path about the preprocessed dataset
base_path = "/content/drive/MyDrive/DiDonato_Giorgi/Preprocessed/Unified"

# path about test, train and validation sets
test_path = "/content/drive/MyDrive/DiDonato_Giorgi/Preprocessed/CLAHE/Test"
val_path = "/content/drive/MyDrive/DiDonato_Giorgi/Preprocessed/CLAHE/Validation"
train_path = "/content/drive/MyDrive/DiDonato_Giorgi/Preprocessed/CLAHE/Train"

models_path = "/content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE"
cnn_results_path = os.path.join(models_path, 'CNN')
vgg16_results_path = os.path.join(models_path, 'VGG16')
resnet50_results_path = os.path.join(models_path, 'ResNet50')
inceptionv3_results_path = os.path.join(models_path, 'InceptionV3')
# actual_results_path = vgg16_results_path

def set_seed ():
	''' 
	set_seed is used to obtain reproducible results using keras during the development phase
	'''
	seed = 10
	# The below is necessary for reproducible results of certain Python hash-based operations.
	os.environ["PYTHONHASHSEED"]="0"
	# The below is necessary for starting Numpy generated random numbers in a well-defined initial state.
	np.random.seed(seed)
	# The below is necessary for starting core Python generated random numbers in a well-defined state.
	rn.seed(seed)
	# The below tf.random.set_seed will make x number generation in TensorFlow have a well-defined initial state.
	tf.random.set_seed(seed)     

# image size
image_size = 224
batch_size = 32

# create the generators for data augmentation with rescaling
data_generator = ImageDataGenerator(rescale=1.0/255.0)

# load train, test and validation sets
train_generator = data_generator.flow_from_directory(
    train_path,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = data_generator.flow_from_directory(
    test_path,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

val_generator = data_generator.flow_from_directory(
    val_path,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical'
)
     

def show_training_and_validation_performance(history,path):
	'''
	show_training_and_validation_performance is used to plot the performances during the training phase
	:param history: object in which are recorded all the events
	'''
	acc = history.history['accuracy']
	val_acc = history.history['val_accuracy']
	loss = history.history['loss']
	val_loss = history.history['val_loss']

	epochs = range(len(acc))

	plt.plot(epochs, acc, 'bo', label='Training accuracy')
	plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
	plt.title('Training and validation accuracy')
	plt.legend()

	plt.figure()

	plt.plot(epochs, loss, 'bo', label='Training loss')
	plt.plot(epochs, val_loss, 'b', label='Validation loss')
	plt.title('Training and validation loss')
	plt.legend()

	plt.savefig(path)

	plt.show()

def compile_model (model, optimizer='adam', learning_rate = 0.001):
	'''
	compile_model is used to compile the current model
	:param model: model to compile
	:param optimizer: optimizer to be used
	:param learning_rate: learning rate parameter for the optimizer
	'''
	if optimizer == 'adam':
		model.compile(loss="categorical_crossentropy",
		optimizer=optimizers.Adam(learning_rate=learning_rate),
		metrics=["accuracy"])
	elif optimizer == 'rmsprop':
		model.compile(loss="categorical_crossentropy",
					optimizer = optimizers.RMSprop(learning_rate=learning_rate),
					metrics=['accuracy'])
	model.summary()

def run_model (model, type, model_name, epochs = 100, patience=5, monitor='val_loss'):
	'''
	run_model is used to run the current mode
	:param model: model to run
	:param model_name: name given to save the model
	:param type: type of model, CNN, VGG16, ResNet50, InceptionV3
	:param epochs: how many epochs to do
	:param patience: patience value for Early Stopping
	:param monitor: what to monitor for Early Stopping and Model Checkpoint
	'''
	# local save path for the models
	save_path = os.path.join(models_path, type + '/' + model_name + '.h5') 
	callbacks_list = [
					keras.callbacks.EarlyStopping(monitor=monitor, patience=patience),
					keras.callbacks.ModelCheckpoint(
						filepath = save_path,
						monitor=monitor,
						verbose=1,
						save_best_only=True)
					]
	history = model.fit(train_generator,
						epochs=epochs,
						validation_data=val_generator,
						callbacks=callbacks_list)
	# save on Drive only the best model
	show_training_and_validation_performance(history,os.path.join(models_path, type + '/' + model_name + '_validation.png'))

def plot_roc_curve(y_true, y_pred, n_classes, class_labels, model_name, type):

    # label conversion to binary format
    lb = LabelBinarizer()
    y_true_binary = lb.fit_transform(y_true)

    # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(n_classes):
        fpr[i], tpr[i], _ = metrics.roc_curve(y_true_binary[:, i], y_pred[:, i])
        roc_auc[i] = metrics.auc(fpr[i], tpr[i])

    plt.figure()
    colors = ['blue', 'red', 'green', 'orange']  

    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, label='ROC curve {0} ({1:0.2f}%)'.format(class_labels[i], roc_auc[i]*100))

    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve')
    plt.legend(loc="lower right")
    plt.savefig(os.path.join(models_path, type + '/' + model_name + '_ROC.png'))
    plt.show()

def evaluate_model (model, test_generator, model_name, type):
	'''
	evaluate_model is used to plot some statistics about the performance on the test set
	:param model: model to consider
	'''
	labels_d= ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

	# get predictions
	y_score = model.predict(test_generator)
	# convert predictions to classes
	y_pred = np.argmax(y_score, axis=-1)
	# get true classes
	y_true = test_generator.classes
	# extract class labels
	class_labels = list(test_generator.class_indices.keys())
	
	print("Classification report: ")
	# create and show classification report
	print(metrics.classification_report(y_true, y_pred, target_names=class_labels,digits = 4))
	# save classification report
	with open(os.path.join(models_path, type + '/' + model_name + '_classification_report.txt'), 'w') as f:
		f.write(metrics.classification_report(y_true, y_pred, target_names=class_labels,digits = 4))

	# create and show confusion matrix	
	cm = confusion_matrix(y_true, y_pred)	
	disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
	disp.plot(xticks_rotation=45)
	
	# save confusion matrix
	plt.savefig(os.path.join(models_path, type, model_name + '_confusion_matrix.png'), bbox_inches='tight', pad_inches=0.1)
	plt.show()

	plot_roc_curve(y_true, y_score, 4, class_labels, model_name, type)

def get_index_by_layer_name(model, layer_name):
  '''
  get_index_by_layer_name is used to retrieve the index of a specific layer
  :param model: model to check
  :param layer_name: name of the layer we want to get the index of
  :return: the index of the layer named as defined in layer_name
  '''
  for index, layer in enumerate(model.layers):
      if layer.name == layer_name:
          return index 

def clear(model):
	del model
	K.clear_session() 

set_seed ()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b7146493b00e> in <cell line: 60>()
#      58
#      59 # Carica le immagini dal set di addestramento
# ---> 60 train_generator = data_generator.flow_from_directory(
#      61     train_path,
#      62     target_size=(image_size, image_size),
#
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1646                 and `y` is a numpy array of corresponding labels.
#    1647         """
# -> 1648         return DirectoryIterator(
#    1649             directory,
#    1650             self,
#
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     589         classes_list = []
#     590         for res in results:
# --> 591             classes, filenames = res.get()
#     592             classes_list.append(classes)
#     593             self.filenames += filenames
#
# /usr/lib/python3.10/multiprocessing/pool.py in get(self, timeout)
#     766
#     767     def get(self, timeout=None):
# --> 768         self.wait(timeout)
#     769         if not self.ready():
#     770             raise TimeoutError
#
# /usr/lib/python3.10/multiprocessing/pool.py in wait(self, timeout)
#     763
#     764     def wait(self, timeout=None):
# --> 765         self._event.wait(timeout)
#     766
#     767     def get(self, timeout=None):
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     605             signaled = self._flag
#     606             if not signaled:
# --> 607                 signaled = self._cond.wait(timeout)
#     608             return signaled
#     609
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     318         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#     322             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Load VGG16

# %%
# Carica il modello VGG16 pre-addestrato, senza l'ultimo strato fully connected
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# ## Experiment 1
# VGG16 + dense layer 128 neuron

# %%
# Aggiungi un nuovo strato fully connected all'ultimo layer di VGG16
inputs = keras.Input(shape=(image_size, image_size, 3))
x = base_model(inputs)
x = layers.Flatten()(x)
x = layers.Dense(128, activation="relu")(x)
outputs = layers.Dense(4, activation="softmax")(x)#4 classi di output
model = keras.Model(inputs=inputs, outputs=outputs)

# Congela i pesi del modello base, così da mantenere l'informazione appresa
for layer in base_model.layers:
    layer.trainable = False

# Compila il modello
compile_model(model)

# Addestra il modello
run_model(model,"VGG16","VGG16_128")

# Valuta il modello
evaluate_model(model,test_generator,"VGG16_128","VGG16")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 17,926,596
# Trainable params: 3,211,908
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.0096 - accuracy: 0.6732
# Epoch 1: val_loss improved from inf to 0.55814, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128.h5
# 142/142 [==============================] - 3191s 22s/step - loss: 1.0096 - accuracy: 0.6732 - val_loss: 0.5581 - val_accuracy: 0.8037
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4094 - accuracy: 0.8566
# Epoch 2: val_loss improved from 0.55814 to 0.38245, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128.h5
# 142/142 [==============================] - 28s 195ms/step - loss: 0.4094 - accuracy: 0.8566 - val_loss: 0.3824 - val_accuracy: 0.8727
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9254
# Epoch 3: val_loss improved from 0.38245 to 0.37354, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128.h5
# 142/142 [==============================] - 30s 208ms/step - loss: 0.2445 - accuracy: 0.9254 - val_loss: 0.3735 - val_accuracy: 0.8681
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9504
# Epoch 4: val_loss improved from 0.37354 to 0.31881, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128.h5
# 142/142 [==============================] - 28s 195ms/step - loss: 0.1753 - accuracy: 0.9504 - val_loss: 0.3188 - val_accuracy: 0.9018
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9739
# Epoch 5: val_loss improved from 0.31881 to 0.29926, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128.h5
# 142/142 [==============================] - 28s 197ms/step - loss: 0.1101 - accuracy: 0.9739 - val_loss: 0.2993 - val_accuracy: 0.9110
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0847 - accuracy: 0.9790
# Epoch 6: val_loss improved from 0.29926 to 0.29736, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128.h5
# 142/142 [==============================] - 28s 193ms/step - loss: 0.0847 - accuracy: 0.9790 - val_loss: 0.2974 - val_accuracy: 0.9156
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9801
# Epoch 7: val_loss did not improve from 0.29736
# 142/142 [==============================] - 26s 180ms/step - loss: 0.0712 - accuracy: 0.9801 - val_loss: 0.3037 - val_accuracy: 0.9110
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9956
# Epoch 8: val_loss did not improve from 0.29736
# 142/142 [==============================] - 26s 183ms/step - loss: 0.0370 - accuracy: 0.9956 - val_loss: 0.3290 - val_accuracy: 0.9049
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9949
# Epoch 9: val_loss did not improve from 0.29736
# 142/142 [==============================] - 26s 181ms/step - loss: 0.0307 - accuracy: 0.9949 - val_loss: 0.3165 - val_accuracy: 0.9095
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9951
# Epoch 10: val_loss did not improve from 0.29736
# 142/142 [==============================] - 26s 184ms/step - loss: 0.0273 - accuracy: 0.9951 - val_loss: 0.3232 - val_accuracy: 0.9080
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9989
# Epoch 11: val_loss did not improve from 0.29736
# 142/142 [==============================] - 26s 181ms/step - loss: 0.0154 - accuracy: 0.9989 - val_loss: 0.3474 - val_accuracy: 0.9156
# 21/21 [==============================] - 485s 24s/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.9364    0.8757    0.9050       185
# meningioma_tumor     0.8462    0.8824    0.8639       187
#         no_tumor     0.9135    0.9500    0.9314       100
#  pituitary_tumor     0.9444    0.9444    0.9444       180
#
#         accuracy                         0.9080       652
#        macro avg     0.9101    0.9131    0.9112       652
#     weighted avg     0.9092    0.9080    0.9081       652

# %% [markdown]
# ## Experiment 2
# VGG16 + dense layer 128 neurons and dropout

# %%
# Aggiungi un nuovo strato fully connected all'ultimo layer di VGG16
inputs = keras.Input(shape=(image_size, image_size, 3))
x = base_model(inputs)
x = layers.Flatten()(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(4, activation="softmax")(x)#4 classi di output
model = keras.Model(inputs=inputs, outputs=outputs)

# Congela i pesi del modello base, così da mantenere l'informazione appresa
for layer in base_model.layers:
    layer.trainable = False

# Compila il modello
compile_model(model)

# Addestra il modello
run_model(model,"VGG16","VGG16_128_dropout")

# Valuta il modello
evaluate_model(model,test_generator,"VGG16_128_dropout","VGG16")
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 128)               3211392
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 17,926,596
# Trainable params: 3,211,908
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.0052 - accuracy: 0.6624
# Epoch 1: val_loss improved from inf to 0.51279, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_dropout.h5
# 142/142 [==============================] - 31s 205ms/step - loss: 1.0052 - accuracy: 0.6624 - val_loss: 0.5128 - val_accuracy: 0.8006
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5009 - accuracy: 0.8031
# Epoch 2: val_loss improved from 0.51279 to 0.41850, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_dropout.h5
# 142/142 [==============================] - 28s 194ms/step - loss: 0.5009 - accuracy: 0.8031 - val_loss: 0.4185 - val_accuracy: 0.8451
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.8150
# Epoch 3: val_loss improved from 0.41850 to 0.39725, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_dropout.h5
# 142/142 [==============================] - 29s 202ms/step - loss: 0.4726 - accuracy: 0.8150 - val_loss: 0.3973 - val_accuracy: 0.8604
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3643 - accuracy: 0.8600
# Epoch 4: val_loss improved from 0.39725 to 0.37565, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_dropout.h5
# 142/142 [==============================] - 27s 190ms/step - loss: 0.3643 - accuracy: 0.8600 - val_loss: 0.3756 - val_accuracy: 0.8620
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.8792
# Epoch 5: val_loss improved from 0.37565 to 0.33867, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_dropout.h5
# 142/142 [==============================] - 28s 194ms/step - loss: 0.3092 - accuracy: 0.8792 - val_loss: 0.3387 - val_accuracy: 0.8758
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2720 - accuracy: 0.8958
# Epoch 6: val_loss improved from 0.33867 to 0.32992, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_dropout.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.2720 - accuracy: 0.8958 - val_loss: 0.3299 - val_accuracy: 0.8865
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.9091
# Epoch 7: val_loss improved from 0.32992 to 0.31846, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_dropout.h5
# 142/142 [==============================] - 28s 194ms/step - loss: 0.2292 - accuracy: 0.9091 - val_loss: 0.3185 - val_accuracy: 0.8942
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9279
# Epoch 8: val_loss did not improve from 0.31846
# 142/142 [==============================] - 27s 190ms/step - loss: 0.1924 - accuracy: 0.9279 - val_loss: 0.3539 - val_accuracy: 0.8942
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1697 - accuracy: 0.9334
# Epoch 9: val_loss did not improve from 0.31846
# 142/142 [==============================] - 25s 176ms/step - loss: 0.1697 - accuracy: 0.9334 - val_loss: 0.3251 - val_accuracy: 0.8942
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9312
# Epoch 10: val_loss did not improve from 0.31846
# 142/142 [==============================] - 26s 180ms/step - loss: 0.1694 - accuracy: 0.9312 - val_loss: 0.3250 - val_accuracy: 0.9064
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9447
# Epoch 11: val_loss did not improve from 0.31846
# 142/142 [==============================] - 26s 179ms/step - loss: 0.1419 - accuracy: 0.9447 - val_loss: 0.3494 - val_accuracy: 0.9034
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1178 - accuracy: 0.9562
# Epoch 12: val_loss did not improve from 0.31846
# 142/142 [==============================] - 25s 177ms/step - loss: 0.1178 - accuracy: 0.9562 - val_loss: 0.3723 - val_accuracy: 0.9110
# 21/21 [==============================] - 3s 146ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.9641    0.8703    0.9148       185
# meningioma_tumor     0.8384    0.8877    0.8623       187
#         no_tumor     0.8727    0.9600    0.9143       100
#  pituitary_tumor     0.9548    0.9389    0.9468       180
#
#         accuracy                         0.9080       652
#        macro avg     0.9075    0.9142    0.9095       652
#     weighted avg     0.9115    0.9080    0.9085       652

# %%
# Aggiungi un nuovo strato fully connected all'ultimo layer di VGG16
inputs = keras.Input(shape=(image_size, image_size, 3))
x = base_model(inputs)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation="relu")(x)
outputs = layers.Dense(4, activation="softmax")(x)#4 classi di output
model = keras.Model(inputs=inputs, outputs=outputs)

# Congela i pesi del modello base, così da mantenere l'informazione appresa
for layer in base_model.layers:
    layer.trainable = False

# Compila il modello
compile_model(model)

# Addestra il modello
run_model(model,"VGG16","VGG16_global_128")

# Valuta il modello
evaluate_model(model,test_generator,"VGG16_global_128","VGG16")
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  dense_5 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 14,780,868
# Trainable params: 66,180
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.0255 - accuracy: 0.5991
# Epoch 1: val_loss improved from inf to 0.80922, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 30s 203ms/step - loss: 1.0255 - accuracy: 0.5991 - val_loss: 0.8092 - val_accuracy: 0.6856
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.7462 - accuracy: 0.7376
# Epoch 2: val_loss improved from 0.80922 to 0.70877, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 28s 198ms/step - loss: 0.7462 - accuracy: 0.7376 - val_loss: 0.7088 - val_accuracy: 0.7638
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6522 - accuracy: 0.7710
# Epoch 3: val_loss improved from 0.70877 to 0.60707, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 27s 187ms/step - loss: 0.6522 - accuracy: 0.7710 - val_loss: 0.6071 - val_accuracy: 0.7699
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5923 - accuracy: 0.7889
# Epoch 4: val_loss improved from 0.60707 to 0.60146, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 27s 188ms/step - loss: 0.5923 - accuracy: 0.7889 - val_loss: 0.6015 - val_accuracy: 0.7531
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5605 - accuracy: 0.8033
# Epoch 5: val_loss improved from 0.60146 to 0.55995, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 26s 185ms/step - loss: 0.5605 - accuracy: 0.8033 - val_loss: 0.5599 - val_accuracy: 0.7791
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5202 - accuracy: 0.8139
# Epoch 6: val_loss did not improve from 0.55995
# 142/142 [==============================] - 25s 175ms/step - loss: 0.5202 - accuracy: 0.8139 - val_loss: 0.5924 - val_accuracy: 0.7837
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4963 - accuracy: 0.8292
# Epoch 7: val_loss improved from 0.55995 to 0.55252, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 26s 186ms/step - loss: 0.4963 - accuracy: 0.8292 - val_loss: 0.5525 - val_accuracy: 0.7715
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4790 - accuracy: 0.8250
# Epoch 8: val_loss improved from 0.55252 to 0.52427, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 27s 186ms/step - loss: 0.4790 - accuracy: 0.8250 - val_loss: 0.5243 - val_accuracy: 0.8083
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4581 - accuracy: 0.8378
# Epoch 9: val_loss improved from 0.52427 to 0.50400, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.4581 - accuracy: 0.8378 - val_loss: 0.5040 - val_accuracy: 0.8206
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4353 - accuracy: 0.8447
# Epoch 10: val_loss improved from 0.50400 to 0.49529, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 27s 187ms/step - loss: 0.4353 - accuracy: 0.8447 - val_loss: 0.4953 - val_accuracy: 0.8160
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4122 - accuracy: 0.8569
# Epoch 11: val_loss did not improve from 0.49529
# 142/142 [==============================] - 26s 180ms/step - loss: 0.4122 - accuracy: 0.8569 - val_loss: 0.5175 - val_accuracy: 0.7899
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4092 - accuracy: 0.8489
# Epoch 12: val_loss improved from 0.49529 to 0.45759, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.4092 - accuracy: 0.8489 - val_loss: 0.4576 - val_accuracy: 0.8144
# Epoch 13/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3900 - accuracy: 0.8639
# Epoch 13: val_loss improved from 0.45759 to 0.45502, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 27s 187ms/step - loss: 0.3900 - accuracy: 0.8639 - val_loss: 0.4550 - val_accuracy: 0.8282
# Epoch 14/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.8706
# Epoch 14: val_loss did not improve from 0.45502
# 142/142 [==============================] - 26s 180ms/step - loss: 0.3726 - accuracy: 0.8706 - val_loss: 0.4927 - val_accuracy: 0.7822
# Epoch 15/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3785 - accuracy: 0.8628
# Epoch 15: val_loss did not improve from 0.45502
# 142/142 [==============================] - 27s 189ms/step - loss: 0.3785 - accuracy: 0.8628 - val_loss: 0.4831 - val_accuracy: 0.8175
# Epoch 16/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3597 - accuracy: 0.8692
# Epoch 16: val_loss did not improve from 0.45502
# 142/142 [==============================] - 25s 179ms/step - loss: 0.3597 - accuracy: 0.8692 - val_loss: 0.4571 - val_accuracy: 0.8298
# Epoch 17/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3439 - accuracy: 0.8768
# Epoch 17: val_loss did not improve from 0.45502
# 142/142 [==============================] - 26s 182ms/step - loss: 0.3439 - accuracy: 0.8768 - val_loss: 0.4589 - val_accuracy: 0.8359
# Epoch 18/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3440 - accuracy: 0.8759
# Epoch 18: val_loss improved from 0.45502 to 0.45222, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 27s 188ms/step - loss: 0.3440 - accuracy: 0.8759 - val_loss: 0.4522 - val_accuracy: 0.8298
# Epoch 19/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3251 - accuracy: 0.8836
# Epoch 19: val_loss improved from 0.45222 to 0.44008, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 28s 197ms/step - loss: 0.3251 - accuracy: 0.8836 - val_loss: 0.4401 - val_accuracy: 0.8390
# Epoch 20/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3191 - accuracy: 0.8865
# Epoch 20: val_loss did not improve from 0.44008
# 142/142 [==============================] - 26s 179ms/step - loss: 0.3191 - accuracy: 0.8865 - val_loss: 0.4554 - val_accuracy: 0.8359
# Epoch 21/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3103 - accuracy: 0.8878
# Epoch 21: val_loss improved from 0.44008 to 0.43206, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 27s 186ms/step - loss: 0.3103 - accuracy: 0.8878 - val_loss: 0.4321 - val_accuracy: 0.8390
# Epoch 22/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2968 - accuracy: 0.8942
# Epoch 22: val_loss did not improve from 0.43206
# 142/142 [==============================] - 25s 178ms/step - loss: 0.2968 - accuracy: 0.8942 - val_loss: 0.4337 - val_accuracy: 0.8436
# Epoch 23/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.8925
# Epoch 23: val_loss improved from 0.43206 to 0.41973, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_128.h5
# 142/142 [==============================] - 27s 188ms/step - loss: 0.2946 - accuracy: 0.8925 - val_loss: 0.4197 - val_accuracy: 0.8436
# Epoch 24/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.8971
# Epoch 24: val_loss did not improve from 0.41973
# 142/142 [==============================] - 26s 180ms/step - loss: 0.2865 - accuracy: 0.8971 - val_loss: 0.5262 - val_accuracy: 0.8328
# Epoch 25/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2790 - accuracy: 0.8980
# Epoch 25: val_loss did not improve from 0.41973
# 142/142 [==============================] - 26s 179ms/step - loss: 0.2790 - accuracy: 0.8980 - val_loss: 0.4756 - val_accuracy: 0.8282
# Epoch 26/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2787 - accuracy: 0.8982
# Epoch 26: val_loss did not improve from 0.41973
# 142/142 [==============================] - 26s 181ms/step - loss: 0.2787 - accuracy: 0.8982 - val_loss: 0.4296 - val_accuracy: 0.8451
# Epoch 27/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2774 - accuracy: 0.9011
# Epoch 27: val_loss did not improve from 0.41973
# 142/142 [==============================] - 25s 179ms/step - loss: 0.2774 - accuracy: 0.9011 - val_loss: 0.4443 - val_accuracy: 0.8512
# Epoch 28/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2618 - accuracy: 0.9071
# Epoch 28: val_loss did not improve from 0.41973
# 142/142 [==============================] - 26s 179ms/step - loss: 0.2618 - accuracy: 0.9071 - val_loss: 0.4339 - val_accuracy: 0.8497
# 21/21 [==============================] - 3s 149ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.8555    0.8000    0.8268       185
# meningioma_tumor     0.7512    0.8396    0.7929       187
#         no_tumor     0.8911    0.9000    0.8955       100
#  pituitary_tumor     0.9527    0.8944    0.9226       180
#
#         accuracy                         0.8528       652
#        macro avg     0.8626    0.8585    0.8595       652
#     weighted avg     0.8579    0.8528    0.8541       652

# %% [markdown]
# ## Experiment 3
# VGG16 + dense layer 256 neurons

# %%
# Aggiungi un nuovo strato fully connected all'ultimo layer di VGG16
inputs = keras.Input(shape=(image_size, image_size, 3))
x = base_model(inputs)
x = layers.Flatten()(x)
x = layers.Dense(256, activation="relu")(x)
outputs = layers.Dense(4, activation="softmax")(x)#4 classi di output
model = keras.Model(inputs=inputs, outputs=outputs)

# Congela i pesi del modello base, così da mantenere l'informazione appresa
for layer in base_model.layers:
    layer.trainable = False

# Compila il modello
compile_model(model)

# Addestra il modello
run_model(model,"VGG16","VGG16_256")

# Valuta il modello
evaluate_model(model,test_generator,"VGG16_256","VGG16")
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_6 (Dense)             (None, 256)               6422784
#
#  dense_7 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 21,138,500
# Trainable params: 6,423,812
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.0155 - accuracy: 0.7022
# Epoch 1: val_loss improved from inf to 0.53994, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256.h5
# 142/142 [==============================] - 32s 215ms/step - loss: 1.0155 - accuracy: 0.7022 - val_loss: 0.5399 - val_accuracy: 0.7822
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.8936
# Epoch 2: val_loss improved from 0.53994 to 0.31594, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256.h5
# 142/142 [==============================] - 28s 193ms/step - loss: 0.2898 - accuracy: 0.8936 - val_loss: 0.3159 - val_accuracy: 0.8942
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.9274
# Epoch 3: val_loss did not improve from 0.31594
# 142/142 [==============================] - 26s 181ms/step - loss: 0.2039 - accuracy: 0.9274 - val_loss: 0.6083 - val_accuracy: 0.8236
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9502
# Epoch 4: val_loss improved from 0.31594 to 0.29294, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256.h5
# 142/142 [==============================] - 28s 194ms/step - loss: 0.1375 - accuracy: 0.9502 - val_loss: 0.2929 - val_accuracy: 0.9049
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9803
# Epoch 5: val_loss did not improve from 0.29294
# 142/142 [==============================] - 25s 177ms/step - loss: 0.0728 - accuracy: 0.9803 - val_loss: 0.4258 - val_accuracy: 0.8865
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9830
# Epoch 6: val_loss improved from 0.29294 to 0.28771, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256.h5
# 142/142 [==============================] - 27s 192ms/step - loss: 0.0583 - accuracy: 0.9830 - val_loss: 0.2877 - val_accuracy: 0.9218
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9965
# Epoch 7: val_loss did not improve from 0.28771
# 142/142 [==============================] - 26s 182ms/step - loss: 0.0240 - accuracy: 0.9965 - val_loss: 0.3730 - val_accuracy: 0.9018
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9987
# Epoch 8: val_loss did not improve from 0.28771
# 142/142 [==============================] - 25s 179ms/step - loss: 0.0161 - accuracy: 0.9987 - val_loss: 0.3110 - val_accuracy: 0.9248
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9985
# Epoch 9: val_loss did not improve from 0.28771
# 142/142 [==============================] - 26s 179ms/step - loss: 0.0143 - accuracy: 0.9985 - val_loss: 0.3373 - val_accuracy: 0.9110
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9998
# Epoch 10: val_loss did not improve from 0.28771
# 142/142 [==============================] - 25s 177ms/step - loss: 0.0068 - accuracy: 0.9998 - val_loss: 0.3296 - val_accuracy: 0.9187
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9980
# Epoch 11: val_loss did not improve from 0.28771
# 142/142 [==============================] - 25s 179ms/step - loss: 0.0115 - accuracy: 0.9980 - val_loss: 0.3913 - val_accuracy: 0.9049
# 21/21 [==============================] - 3s 161ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.9341    0.8432    0.8864       185
# meningioma_tumor     0.8177    0.8877    0.8513       187
#         no_tumor     0.9048    0.9500    0.9268       100
#  pituitary_tumor     0.9605    0.9444    0.9524       180
#
#         accuracy                         0.9003       652
#        macro avg     0.9043    0.9063    0.9042       652
#     weighted avg     0.9035    0.9003    0.9007       652

# %% [markdown]
# ## Experiment 4
# VGG16 + dense layer 256 neurons and dropout

# %%
# Aggiungi un nuovo strato fully connected all'ultimo layer di VGG16
inputs = keras.Input(shape=(image_size, image_size, 3))
x = base_model(inputs)
x = layers.Flatten()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(4, activation="softmax")(x)#4 classi di output
model = keras.Model(inputs=inputs, outputs=outputs)

# Congela i pesi del modello base, così da mantenere l'informazione appresa
for layer in base_model.layers:
    layer.trainable = False

# Compila il modello
compile_model(model)

# Addestra il modello
run_model(model,"VGG16","VGG16_256_dropout")

# Valuta il modello
evaluate_model(model,test_generator,"VGG16_256_dropout","VGG16")
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  dense_8 (Dense)             (None, 256)               6422784
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 21,138,500
# Trainable params: 6,423,812
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.3113 - accuracy: 0.6274
# Epoch 1: val_loss improved from inf to 0.52797, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256_dropout.h5
# 142/142 [==============================] - 32s 214ms/step - loss: 1.3113 - accuracy: 0.6274 - val_loss: 0.5280 - val_accuracy: 0.8206
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5441 - accuracy: 0.7934
# Epoch 2: val_loss improved from 0.52797 to 0.44616, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256_dropout.h5
# 142/142 [==============================] - 28s 193ms/step - loss: 0.5441 - accuracy: 0.7934 - val_loss: 0.4462 - val_accuracy: 0.8344
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4285 - accuracy: 0.8358
# Epoch 3: val_loss improved from 0.44616 to 0.42266, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256_dropout.h5
# 142/142 [==============================] - 28s 194ms/step - loss: 0.4285 - accuracy: 0.8358 - val_loss: 0.4227 - val_accuracy: 0.8466
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3130 - accuracy: 0.8838
# Epoch 4: val_loss improved from 0.42266 to 0.39005, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256_dropout.h5
# 142/142 [==============================] - 27s 191ms/step - loss: 0.3130 - accuracy: 0.8838 - val_loss: 0.3901 - val_accuracy: 0.8574
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.9033
# Epoch 5: val_loss improved from 0.39005 to 0.38398, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256_dropout.h5
# 142/142 [==============================] - 28s 195ms/step - loss: 0.2580 - accuracy: 0.9033 - val_loss: 0.3840 - val_accuracy: 0.8666
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.9084
# Epoch 6: val_loss improved from 0.38398 to 0.37388, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256_dropout.h5
# 142/142 [==============================] - 29s 204ms/step - loss: 0.2450 - accuracy: 0.9084 - val_loss: 0.3739 - val_accuracy: 0.8512
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.9248
# Epoch 7: val_loss improved from 0.37388 to 0.36235, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256_dropout.h5
# 142/142 [==============================] - 28s 195ms/step - loss: 0.2026 - accuracy: 0.9248 - val_loss: 0.3623 - val_accuracy: 0.8834
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9438
# Epoch 8: val_loss improved from 0.36235 to 0.32406, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256_dropout.h5
# 142/142 [==============================] - 28s 196ms/step - loss: 0.1545 - accuracy: 0.9438 - val_loss: 0.3241 - val_accuracy: 0.8742
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9436
# Epoch 9: val_loss did not improve from 0.32406
# 142/142 [==============================] - 25s 177ms/step - loss: 0.1472 - accuracy: 0.9436 - val_loss: 0.3285 - val_accuracy: 0.9034
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1229 - accuracy: 0.9542
# Epoch 10: val_loss did not improve from 0.32406
# 142/142 [==============================] - 26s 179ms/step - loss: 0.1229 - accuracy: 0.9542 - val_loss: 0.3359 - val_accuracy: 0.8972
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1354 - accuracy: 0.9524
# Epoch 11: val_loss improved from 0.32406 to 0.31012, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_256_dropout.h5
# 142/142 [==============================] - 27s 192ms/step - loss: 0.1354 - accuracy: 0.9524 - val_loss: 0.3101 - val_accuracy: 0.9095
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9584
# Epoch 12: val_loss did not improve from 0.31012
# 142/142 [==============================] - 26s 185ms/step - loss: 0.1182 - accuracy: 0.9584 - val_loss: 0.3729 - val_accuracy: 0.8834
# Epoch 13/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9522
# Epoch 13: val_loss did not improve from 0.31012
# 142/142 [==============================] - 26s 181ms/step - loss: 0.1212 - accuracy: 0.9522 - val_loss: 0.3211 - val_accuracy: 0.9126
# Epoch 14/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9566
# Epoch 14: val_loss did not improve from 0.31012
# 142/142 [==============================] - 27s 189ms/step - loss: 0.1170 - accuracy: 0.9566 - val_loss: 0.3842 - val_accuracy: 0.8957
# Epoch 15/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9467
# Epoch 15: val_loss did not improve from 0.31012
# 142/142 [==============================] - 26s 181ms/step - loss: 0.1408 - accuracy: 0.9467 - val_loss: 0.4046 - val_accuracy: 0.8942
# Epoch 16/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9498
# Epoch 16: val_loss did not improve from 0.31012
# 142/142 [==============================] - 26s 181ms/step - loss: 0.1309 - accuracy: 0.9498 - val_loss: 0.3488 - val_accuracy: 0.9049
# 21/21 [==============================] - 3s 146ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.8930    0.9027    0.8978       185
# meningioma_tumor     0.8376    0.8824    0.8594       187
#         no_tumor     0.9583    0.9200    0.9388       100
#  pituitary_tumor     0.9651    0.9222    0.9432       180
#
#         accuracy                         0.9049       652
#        macro avg     0.9135    0.9068    0.9098       652
#     weighted avg     0.9070    0.9049    0.9056       652

# %%
# Aggiungi un nuovo strato fully connected all'ultimo layer di VGG16
inputs = keras.Input(shape=(image_size, image_size, 3))
x = base_model(inputs)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation="relu")(x)
outputs = layers.Dense(4, activation="softmax")(x)#4 classi di output
model = keras.Model(inputs=inputs, outputs=outputs)

# Congela i pesi del modello base, così da mantenere l'informazione appresa
for layer in base_model.layers:
    layer.trainable = False

# Compila il modello
compile_model(model)

# Addestra il modello
run_model(model,"VGG16","VGG16_global_256")

# Valuta il modello
evaluate_model(model,test_generator,"VGG16_global_256","VGG16")
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_10 (Dense)            (None, 256)               131328
#
#  dense_11 (Dense)            (None, 4)                 1028
#
# =================================================================
# Total params: 14,847,044
# Trainable params: 132,356
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.0206 - accuracy: 0.6002
# Epoch 1: val_loss improved from inf to 0.77164, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 30s 204ms/step - loss: 1.0206 - accuracy: 0.6002 - val_loss: 0.7716 - val_accuracy: 0.7423
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.7264 - accuracy: 0.7434
# Epoch 2: val_loss improved from 0.77164 to 0.65504, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 27s 186ms/step - loss: 0.7264 - accuracy: 0.7434 - val_loss: 0.6550 - val_accuracy: 0.7393
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6408 - accuracy: 0.7715
# Epoch 3: val_loss improved from 0.65504 to 0.58951, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 27s 188ms/step - loss: 0.6408 - accuracy: 0.7715 - val_loss: 0.5895 - val_accuracy: 0.7745
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5745 - accuracy: 0.7907
# Epoch 4: val_loss improved from 0.58951 to 0.57409, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 28s 198ms/step - loss: 0.5745 - accuracy: 0.7907 - val_loss: 0.5741 - val_accuracy: 0.7745
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5399 - accuracy: 0.8035
# Epoch 5: val_loss improved from 0.57409 to 0.55477, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.5399 - accuracy: 0.8035 - val_loss: 0.5548 - val_accuracy: 0.7837
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5022 - accuracy: 0.8190
# Epoch 6: val_loss improved from 0.55477 to 0.52308, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 27s 192ms/step - loss: 0.5022 - accuracy: 0.8190 - val_loss: 0.5231 - val_accuracy: 0.7945
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.8296
# Epoch 7: val_loss did not improve from 0.52308
# 142/142 [==============================] - 26s 183ms/step - loss: 0.4759 - accuracy: 0.8296 - val_loss: 0.5714 - val_accuracy: 0.7699
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.8323
# Epoch 8: val_loss did not improve from 0.52308
# 142/142 [==============================] - 27s 190ms/step - loss: 0.4622 - accuracy: 0.8323 - val_loss: 0.5669 - val_accuracy: 0.7776
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.8451
# Epoch 9: val_loss improved from 0.52308 to 0.49570, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 27s 188ms/step - loss: 0.4334 - accuracy: 0.8451 - val_loss: 0.4957 - val_accuracy: 0.8067
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4340 - accuracy: 0.8363
# Epoch 10: val_loss improved from 0.49570 to 0.46350, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 28s 197ms/step - loss: 0.4340 - accuracy: 0.8363 - val_loss: 0.4635 - val_accuracy: 0.8206
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3857 - accuracy: 0.8626
# Epoch 11: val_loss improved from 0.46350 to 0.46123, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 27s 187ms/step - loss: 0.3857 - accuracy: 0.8626 - val_loss: 0.4612 - val_accuracy: 0.8282
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3651 - accuracy: 0.8684
# Epoch 12: val_loss improved from 0.46123 to 0.45998, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 26s 185ms/step - loss: 0.3651 - accuracy: 0.8684 - val_loss: 0.4600 - val_accuracy: 0.8298
# Epoch 13/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3554 - accuracy: 0.8686
# Epoch 13: val_loss improved from 0.45998 to 0.43873, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 27s 187ms/step - loss: 0.3554 - accuracy: 0.8686 - val_loss: 0.4387 - val_accuracy: 0.8267
# Epoch 14/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.8772
# Epoch 14: val_loss improved from 0.43873 to 0.43365, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 26s 185ms/step - loss: 0.3366 - accuracy: 0.8772 - val_loss: 0.4336 - val_accuracy: 0.8313
# Epoch 15/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.8832
# Epoch 15: val_loss did not improve from 0.43365
# 142/142 [==============================] - 27s 189ms/step - loss: 0.3309 - accuracy: 0.8832 - val_loss: 0.5249 - val_accuracy: 0.7837
# Epoch 16/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3141 - accuracy: 0.8863
# Epoch 16: val_loss did not improve from 0.43365
# 142/142 [==============================] - 25s 176ms/step - loss: 0.3141 - accuracy: 0.8863 - val_loss: 0.4835 - val_accuracy: 0.8190
# Epoch 17/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.8912
# Epoch 17: val_loss did not improve from 0.43365
# 142/142 [==============================] - 25s 177ms/step - loss: 0.3092 - accuracy: 0.8912 - val_loss: 0.5212 - val_accuracy: 0.8252
# Epoch 18/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2891 - accuracy: 0.9020
# Epoch 18: val_loss did not improve from 0.43365
# 142/142 [==============================] - 25s 178ms/step - loss: 0.2891 - accuracy: 0.9020 - val_loss: 0.4359 - val_accuracy: 0.8298
# Epoch 19/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2751 - accuracy: 0.9038
# Epoch 19: val_loss improved from 0.43365 to 0.40835, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.2751 - accuracy: 0.9038 - val_loss: 0.4084 - val_accuracy: 0.8390
# Epoch 20/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.9095
# Epoch 20: val_loss did not improve from 0.40835
# 142/142 [==============================] - 26s 179ms/step - loss: 0.2581 - accuracy: 0.9095 - val_loss: 0.4204 - val_accuracy: 0.8528
# Epoch 21/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2640 - accuracy: 0.9046
# Epoch 21: val_loss did not improve from 0.40835
# 142/142 [==============================] - 26s 180ms/step - loss: 0.2640 - accuracy: 0.9046 - val_loss: 0.4489 - val_accuracy: 0.8221
# Epoch 22/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2551 - accuracy: 0.9077
# Epoch 22: val_loss did not improve from 0.40835
# 142/142 [==============================] - 25s 177ms/step - loss: 0.2551 - accuracy: 0.9077 - val_loss: 0.4405 - val_accuracy: 0.8466
# Epoch 23/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2418 - accuracy: 0.9179
# Epoch 23: val_loss did not improve from 0.40835
# 142/142 [==============================] - 25s 177ms/step - loss: 0.2418 - accuracy: 0.9179 - val_loss: 0.4742 - val_accuracy: 0.8221
# Epoch 24/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2306 - accuracy: 0.9257
# Epoch 24: val_loss did not improve from 0.40835
# 142/142 [==============================] - 26s 179ms/step - loss: 0.2306 - accuracy: 0.9257 - val_loss: 0.4196 - val_accuracy: 0.8620
# 21/21 [==============================] - 3s 145ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.8376    0.8919    0.8639       185
# meningioma_tumor     0.8278    0.7968    0.8120       187
#         no_tumor     0.8598    0.9200    0.8889       100
#  pituitary_tumor     0.9583    0.8944    0.9253       180
#
#         accuracy                         0.8696       652
#        macro avg     0.8709    0.8758    0.8725       652
#     weighted avg     0.8715    0.8696    0.8698       652

# %% [markdown]
# ## Experiment 5
# VGG16 + 2 dense layer 128 neurons and dropout

# %%
# Aggiungi un nuovo strato fully connected all'ultimo layer di VGG16
inputs = keras.Input(shape=(image_size, image_size, 3))
x = base_model(inputs)
x = layers.Flatten()(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(4, activation="softmax")(x)#4 classi di output
model = keras.Model(inputs=inputs, outputs=outputs)

# Congela i pesi del modello base, così da mantenere l'informazione appresa
for layer in base_model.layers:
    layer.trainable = False

# Compila il modello
compile_model(model)

# Addestra il modello
run_model(model,"VGG16","VGG16_128_128_dropout",100,10)

# Valuta il modello
evaluate_model(model,test_generator,"VGG16_128_128_dropout","VGG16")
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_4 (Flatten)         (None, 25088)             0
#
#  dense_12 (Dense)            (None, 128)               3211392
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 17,943,108
# Trainable params: 3,228,420
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.1570 - accuracy: 0.5046
# Epoch 1: val_loss improved from inf to 0.58362, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_128_dropout.h5
# 142/142 [==============================] - 31s 207ms/step - loss: 1.1570 - accuracy: 0.5046 - val_loss: 0.5836 - val_accuracy: 0.7945
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.8135 - accuracy: 0.6458
# Epoch 2: val_loss improved from 0.58362 to 0.53158, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_128_dropout.h5
# 142/142 [==============================] - 28s 197ms/step - loss: 0.8135 - accuracy: 0.6458 - val_loss: 0.5316 - val_accuracy: 0.8021
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6724 - accuracy: 0.7024
# Epoch 3: val_loss improved from 0.53158 to 0.47240, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_128_dropout.h5
# 142/142 [==============================] - 28s 196ms/step - loss: 0.6724 - accuracy: 0.7024 - val_loss: 0.4724 - val_accuracy: 0.8466
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6290 - accuracy: 0.7230
# Epoch 4: val_loss did not improve from 0.47240
# 142/142 [==============================] - 26s 184ms/step - loss: 0.6290 - accuracy: 0.7230 - val_loss: 0.5291 - val_accuracy: 0.8129
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6711 - accuracy: 0.7051
# Epoch 5: val_loss did not improve from 0.47240
# 142/142 [==============================] - 26s 182ms/step - loss: 0.6711 - accuracy: 0.7051 - val_loss: 0.4955 - val_accuracy: 0.8451
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6595 - accuracy: 0.7239
# Epoch 6: val_loss improved from 0.47240 to 0.47064, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_128_dropout.h5
# 142/142 [==============================] - 29s 204ms/step - loss: 0.6595 - accuracy: 0.7239 - val_loss: 0.4706 - val_accuracy: 0.8267
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6188 - accuracy: 0.7347
# Epoch 7: val_loss improved from 0.47064 to 0.43213, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_128_dropout.h5
# 142/142 [==============================] - 28s 198ms/step - loss: 0.6188 - accuracy: 0.7347 - val_loss: 0.4321 - val_accuracy: 0.8681
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6105 - accuracy: 0.7471
# Epoch 8: val_loss did not improve from 0.43213
# 142/142 [==============================] - 26s 186ms/step - loss: 0.6105 - accuracy: 0.7471 - val_loss: 0.5230 - val_accuracy: 0.8390
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5687 - accuracy: 0.7580
# Epoch 9: val_loss did not improve from 0.43213
# 142/142 [==============================] - 26s 182ms/step - loss: 0.5687 - accuracy: 0.7580 - val_loss: 0.4626 - val_accuracy: 0.8589
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6136 - accuracy: 0.7381
# Epoch 10: val_loss did not improve from 0.43213
# 142/142 [==============================] - 26s 180ms/step - loss: 0.6136 - accuracy: 0.7381 - val_loss: 0.4532 - val_accuracy: 0.8482
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5806 - accuracy: 0.7544
# Epoch 11: val_loss improved from 0.43213 to 0.39058, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_128_dropout.h5
# 142/142 [==============================] - 27s 191ms/step - loss: 0.5806 - accuracy: 0.7544 - val_loss: 0.3906 - val_accuracy: 0.8896
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5704 - accuracy: 0.7542
# Epoch 12: val_loss did not improve from 0.39058
# 142/142 [==============================] - 25s 178ms/step - loss: 0.5704 - accuracy: 0.7542 - val_loss: 0.4805 - val_accuracy: 0.8620
# Epoch 13/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5301 - accuracy: 0.7723
# Epoch 13: val_loss did not improve from 0.39058
# 142/142 [==============================] - 26s 180ms/step - loss: 0.5301 - accuracy: 0.7723 - val_loss: 0.3954 - val_accuracy: 0.8804
# Epoch 14/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5132 - accuracy: 0.7774
# Epoch 14: val_loss improved from 0.39058 to 0.37445, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_128_128_dropout.h5
# 142/142 [==============================] - 29s 203ms/step - loss: 0.5132 - accuracy: 0.7774 - val_loss: 0.3745 - val_accuracy: 0.8804
# Epoch 15/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5009 - accuracy: 0.7792
# Epoch 15: val_loss did not improve from 0.37445
# 142/142 [==============================] - 26s 186ms/step - loss: 0.5009 - accuracy: 0.7792 - val_loss: 0.4759 - val_accuracy: 0.8758
# Epoch 16/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4947 - accuracy: 0.7796
# Epoch 16: val_loss did not improve from 0.37445
# 142/142 [==============================] - 26s 185ms/step - loss: 0.4947 - accuracy: 0.7796 - val_loss: 0.4224 - val_accuracy: 0.8819
# Epoch 17/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5950 - accuracy: 0.7277
# Epoch 17: val_loss did not improve from 0.37445
# 142/142 [==============================] - 26s 179ms/step - loss: 0.5950 - accuracy: 0.7277 - val_loss: 0.4646 - val_accuracy: 0.8313
# Epoch 18/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6210 - accuracy: 0.7436
# Epoch 18: val_loss did not improve from 0.37445
# 142/142 [==============================] - 26s 180ms/step - loss: 0.6210 - accuracy: 0.7436 - val_loss: 0.4549 - val_accuracy: 0.8666
# Epoch 19/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4926 - accuracy: 0.7664
# Epoch 19: val_loss did not improve from 0.37445
# 142/142 [==============================] - 26s 182ms/step - loss: 0.4926 - accuracy: 0.7664 - val_loss: 0.4339 - val_accuracy: 0.8528
# Epoch 20/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4693 - accuracy: 0.7858
# Epoch 20: val_loss did not improve from 0.37445
# 142/142 [==============================] - 26s 182ms/step - loss: 0.4693 - accuracy: 0.7858 - val_loss: 0.4494 - val_accuracy: 0.8788
# Epoch 21/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4495 - accuracy: 0.7881
# Epoch 21: val_loss did not improve from 0.37445
# 142/142 [==============================] - 26s 182ms/step - loss: 0.4495 - accuracy: 0.7881 - val_loss: 0.3995 - val_accuracy: 0.8758
# Epoch 22/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4763 - accuracy: 0.7726
# Epoch 22: val_loss did not improve from 0.37445
# 142/142 [==============================] - 25s 179ms/step - loss: 0.4763 - accuracy: 0.7726 - val_loss: 0.4422 - val_accuracy: 0.8758
# Epoch 23/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5255 - accuracy: 0.7518
# Epoch 23: val_loss did not improve from 0.37445
# 142/142 [==============================] - 26s 179ms/step - loss: 0.5255 - accuracy: 0.7518 - val_loss: 0.7569 - val_accuracy: 0.7316
# Epoch 24/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5703 - accuracy: 0.7221
# Epoch 24: val_loss did not improve from 0.37445
# 142/142 [==============================] - 26s 179ms/step - loss: 0.5703 - accuracy: 0.7221 - val_loss: 0.3927 - val_accuracy: 0.8758
# 21/21 [==============================] - 3s 146ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.9259    0.8108    0.8646       185
# meningioma_tumor     0.7443    0.8717    0.8030       187
#         no_tumor     0.9670    0.8800    0.9215       100
#  pituitary_tumor     0.9389    0.9389    0.9389       180
#
#         accuracy                         0.8742       652
#        macro avg     0.8940    0.8753    0.8820       652
#     weighted avg     0.8837    0.8742    0.8761       652

# %% [markdown]
# ## Experiment 6
# VGG16 + GlobalAvgPooling + 2 dense layer 256 neurons and dropout

# %%
# Aggiungi un nuovo strato fully connected all'ultimo layer di VGG16
inputs = keras.Input(shape=(image_size, image_size, 3))
x = base_model(inputs)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation="softmax")(x)#4 classi di output
model = keras.Model(inputs=inputs, outputs=outputs)

# Congela i pesi del modello base, così da mantenere l'informazione appresa
for layer in base_model.layers:
    layer.trainable = False

# Compila il modello
compile_model(model)

# Addestra il modello
run_model(model,"VGG16","VGG16_global_256_256_dropout",100,10)

# Valuta il modello
evaluate_model(model,test_generator,"VGG16_global_256_256_dropout","VGG16")
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_2   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_15 (Dense)            (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_16 (Dense)            (None, 256)               65792
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_17 (Dense)            (None, 4)                 1028
#
# =================================================================
# Total params: 14,912,836
# Trainable params: 198,148
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.2208 - accuracy: 0.4440
# Epoch 1: val_loss improved from inf to 0.88335, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 30s 203ms/step - loss: 1.2208 - accuracy: 0.4440 - val_loss: 0.8834 - val_accuracy: 0.6564
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.8755 - accuracy: 0.6502
# Epoch 2: val_loss improved from 0.88335 to 0.67901, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 27s 188ms/step - loss: 0.8755 - accuracy: 0.6502 - val_loss: 0.6790 - val_accuracy: 0.7439
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.7596 - accuracy: 0.7102
# Epoch 3: val_loss improved from 0.67901 to 0.60248, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 28s 200ms/step - loss: 0.7596 - accuracy: 0.7102 - val_loss: 0.6025 - val_accuracy: 0.7638
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6945 - accuracy: 0.7343
# Epoch 4: val_loss improved from 0.60248 to 0.57789, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.6945 - accuracy: 0.7343 - val_loss: 0.5779 - val_accuracy: 0.7776
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6432 - accuracy: 0.7611
# Epoch 5: val_loss improved from 0.57789 to 0.55072, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 27s 188ms/step - loss: 0.6432 - accuracy: 0.7611 - val_loss: 0.5507 - val_accuracy: 0.7853
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6052 - accuracy: 0.7710
# Epoch 6: val_loss improved from 0.55072 to 0.53926, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 27s 187ms/step - loss: 0.6052 - accuracy: 0.7710 - val_loss: 0.5393 - val_accuracy: 0.7791
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5799 - accuracy: 0.7816
# Epoch 7: val_loss improved from 0.53926 to 0.50708, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 28s 195ms/step - loss: 0.5799 - accuracy: 0.7816 - val_loss: 0.5071 - val_accuracy: 0.7945
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5666 - accuracy: 0.7825
# Epoch 8: val_loss did not improve from 0.50708
# 142/142 [==============================] - 25s 175ms/step - loss: 0.5666 - accuracy: 0.7825 - val_loss: 0.5141 - val_accuracy: 0.7899
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5629 - accuracy: 0.7803
# Epoch 9: val_loss improved from 0.50708 to 0.50316, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 26s 185ms/step - loss: 0.5629 - accuracy: 0.7803 - val_loss: 0.5032 - val_accuracy: 0.7960
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5520 - accuracy: 0.7850
# Epoch 10: val_loss improved from 0.50316 to 0.48104, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.5520 - accuracy: 0.7850 - val_loss: 0.4810 - val_accuracy: 0.8052
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5273 - accuracy: 0.7942
# Epoch 11: val_loss did not improve from 0.48104
# 142/142 [==============================] - 25s 176ms/step - loss: 0.5273 - accuracy: 0.7942 - val_loss: 0.4980 - val_accuracy: 0.8190
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5198 - accuracy: 0.8046
# Epoch 12: val_loss improved from 0.48104 to 0.47108, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 26s 185ms/step - loss: 0.5198 - accuracy: 0.8046 - val_loss: 0.4711 - val_accuracy: 0.8098
# Epoch 13/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.8124
# Epoch 13: val_loss did not improve from 0.47108
# 142/142 [==============================] - 25s 176ms/step - loss: 0.4871 - accuracy: 0.8124 - val_loss: 0.4773 - val_accuracy: 0.8144
# Epoch 14/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5207 - accuracy: 0.8027
# Epoch 14: val_loss did not improve from 0.47108
# 142/142 [==============================] - 25s 178ms/step - loss: 0.5207 - accuracy: 0.8027 - val_loss: 0.4762 - val_accuracy: 0.8006
# Epoch 15/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4956 - accuracy: 0.8053
# Epoch 15: val_loss improved from 0.47108 to 0.45568, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 26s 184ms/step - loss: 0.4956 - accuracy: 0.8053 - val_loss: 0.4557 - val_accuracy: 0.8160
# Epoch 16/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4822 - accuracy: 0.8150
# Epoch 16: val_loss did not improve from 0.45568
# 142/142 [==============================] - 26s 179ms/step - loss: 0.4822 - accuracy: 0.8150 - val_loss: 0.4603 - val_accuracy: 0.8236
# Epoch 17/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4866 - accuracy: 0.8093
# Epoch 17: val_loss improved from 0.45568 to 0.44750, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.4866 - accuracy: 0.8093 - val_loss: 0.4475 - val_accuracy: 0.8144
# Epoch 18/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4566 - accuracy: 0.8223
# Epoch 18: val_loss did not improve from 0.44750
# 142/142 [==============================] - 25s 177ms/step - loss: 0.4566 - accuracy: 0.8223 - val_loss: 0.4681 - val_accuracy: 0.8067
# Epoch 19/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4669 - accuracy: 0.8195
# Epoch 19: val_loss did not improve from 0.44750
# 142/142 [==============================] - 25s 176ms/step - loss: 0.4669 - accuracy: 0.8195 - val_loss: 0.4729 - val_accuracy: 0.8067
# Epoch 20/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4484 - accuracy: 0.8299
# Epoch 20: val_loss did not improve from 0.44750
# 142/142 [==============================] - 25s 178ms/step - loss: 0.4484 - accuracy: 0.8299 - val_loss: 0.4625 - val_accuracy: 0.8252
# Epoch 21/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4548 - accuracy: 0.8208
# Epoch 21: val_loss improved from 0.44750 to 0.42418, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 26s 185ms/step - loss: 0.4548 - accuracy: 0.8208 - val_loss: 0.4242 - val_accuracy: 0.8282
# Epoch 22/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4405 - accuracy: 0.8285
# Epoch 22: val_loss did not improve from 0.42418
# 142/142 [==============================] - 25s 176ms/step - loss: 0.4405 - accuracy: 0.8285 - val_loss: 0.4296 - val_accuracy: 0.8328
# Epoch 23/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4111 - accuracy: 0.8460
# Epoch 23: val_loss did not improve from 0.42418
# 142/142 [==============================] - 25s 177ms/step - loss: 0.4111 - accuracy: 0.8460 - val_loss: 0.4333 - val_accuracy: 0.8282
# Epoch 24/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4108 - accuracy: 0.8429
# Epoch 24: val_loss did not improve from 0.42418
# 142/142 [==============================] - 25s 178ms/step - loss: 0.4108 - accuracy: 0.8429 - val_loss: 0.4776 - val_accuracy: 0.8175
# Epoch 25/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4088 - accuracy: 0.8369
# Epoch 25: val_loss did not improve from 0.42418
# 142/142 [==============================] - 25s 175ms/step - loss: 0.4088 - accuracy: 0.8369 - val_loss: 0.4488 - val_accuracy: 0.8252
# Epoch 26/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3998 - accuracy: 0.8447
# Epoch 26: val_loss did not improve from 0.42418
# 142/142 [==============================] - 25s 175ms/step - loss: 0.3998 - accuracy: 0.8447 - val_loss: 0.4488 - val_accuracy: 0.8313
# Epoch 27/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4137 - accuracy: 0.8374
# Epoch 27: val_loss did not improve from 0.42418
# 142/142 [==============================] - 25s 175ms/step - loss: 0.4137 - accuracy: 0.8374 - val_loss: 0.4474 - val_accuracy: 0.8328
# Epoch 28/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4254 - accuracy: 0.8352
# Epoch 28: val_loss improved from 0.42418 to 0.42329, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.4254 - accuracy: 0.8352 - val_loss: 0.4233 - val_accuracy: 0.8344
# Epoch 29/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4122 - accuracy: 0.8376
# Epoch 29: val_loss did not improve from 0.42329
# 142/142 [==============================] - 25s 174ms/step - loss: 0.4122 - accuracy: 0.8376 - val_loss: 0.4510 - val_accuracy: 0.8282
# Epoch 30/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4071 - accuracy: 0.8427
# Epoch 30: val_loss did not improve from 0.42329
# 142/142 [==============================] - 26s 185ms/step - loss: 0.4071 - accuracy: 0.8427 - val_loss: 0.4664 - val_accuracy: 0.8282
# Epoch 31/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4123 - accuracy: 0.8374
# Epoch 31: val_loss did not improve from 0.42329
# 142/142 [==============================] - 25s 176ms/step - loss: 0.4123 - accuracy: 0.8374 - val_loss: 0.4274 - val_accuracy: 0.8236
# Epoch 32/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3846 - accuracy: 0.8485
# Epoch 32: val_loss did not improve from 0.42329
# 142/142 [==============================] - 25s 174ms/step - loss: 0.3846 - accuracy: 0.8485 - val_loss: 0.4308 - val_accuracy: 0.8405
# Epoch 33/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3817 - accuracy: 0.8520
# Epoch 33: val_loss did not improve from 0.42329
# 142/142 [==============================] - 27s 187ms/step - loss: 0.3817 - accuracy: 0.8520 - val_loss: 0.4322 - val_accuracy: 0.8436
# Epoch 34/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4034 - accuracy: 0.8423
# Epoch 34: val_loss did not improve from 0.42329
# 142/142 [==============================] - 25s 175ms/step - loss: 0.4034 - accuracy: 0.8423 - val_loss: 0.4562 - val_accuracy: 0.8451
# Epoch 35/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3801 - accuracy: 0.8456
# Epoch 35: val_loss did not improve from 0.42329
# 142/142 [==============================] - 24s 172ms/step - loss: 0.3801 - accuracy: 0.8456 - val_loss: 0.4281 - val_accuracy: 0.8374
# Epoch 36/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.8460
# Epoch 36: val_loss did not improve from 0.42329
# 142/142 [==============================] - 25s 177ms/step - loss: 0.3882 - accuracy: 0.8460 - val_loss: 0.4296 - val_accuracy: 0.8451
# Epoch 37/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3511 - accuracy: 0.8664
# Epoch 37: val_loss did not improve from 0.42329
# 142/142 [==============================] - 25s 175ms/step - loss: 0.3511 - accuracy: 0.8664 - val_loss: 0.4328 - val_accuracy: 0.8405
# Epoch 38/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3756 - accuracy: 0.8515
# Epoch 38: val_loss improved from 0.42329 to 0.41426, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 28s 200ms/step - loss: 0.3756 - accuracy: 0.8515 - val_loss: 0.4143 - val_accuracy: 0.8451
# Epoch 39/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 0.8675
# Epoch 39: val_loss did not improve from 0.41426
# 142/142 [==============================] - 25s 176ms/step - loss: 0.3328 - accuracy: 0.8675 - val_loss: 0.5086 - val_accuracy: 0.8144
# Epoch 40/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3439 - accuracy: 0.8662
# Epoch 40: val_loss did not improve from 0.41426
# 142/142 [==============================] - 26s 180ms/step - loss: 0.3439 - accuracy: 0.8662 - val_loss: 0.4637 - val_accuracy: 0.8359
# Epoch 41/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3380 - accuracy: 0.8710
# Epoch 41: val_loss did not improve from 0.41426
# 142/142 [==============================] - 25s 175ms/step - loss: 0.3380 - accuracy: 0.8710 - val_loss: 0.4287 - val_accuracy: 0.8482
# Epoch 42/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3397 - accuracy: 0.8673
# Epoch 42: val_loss did not improve from 0.41426
# 142/142 [==============================] - 27s 187ms/step - loss: 0.3397 - accuracy: 0.8673 - val_loss: 0.4236 - val_accuracy: 0.8497
# Epoch 43/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3399 - accuracy: 0.8719
# Epoch 43: val_loss improved from 0.41426 to 0.40730, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/VGG16/VGG16_global_256_256_dropout.h5
# 142/142 [==============================] - 26s 182ms/step - loss: 0.3399 - accuracy: 0.8719 - val_loss: 0.4073 - val_accuracy: 0.8436
# Epoch 44/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3362 - accuracy: 0.8681
# Epoch 44: val_loss did not improve from 0.40730
# 142/142 [==============================] - 25s 177ms/step - loss: 0.3362 - accuracy: 0.8681 - val_loss: 0.4324 - val_accuracy: 0.8451
# Epoch 45/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.8624
# Epoch 45: val_loss did not improve from 0.40730
# 142/142 [==============================] - 25s 176ms/step - loss: 0.3492 - accuracy: 0.8624 - val_loss: 0.4293 - val_accuracy: 0.8451
# Epoch 46/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.8628
# Epoch 46: val_loss did not improve from 0.40730
# 142/142 [==============================] - 27s 187ms/step - loss: 0.3409 - accuracy: 0.8628 - val_loss: 0.4255 - val_accuracy: 0.8528
# Epoch 47/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3469 - accuracy: 0.8659
# Epoch 47: val_loss did not improve from 0.40730
# 142/142 [==============================] - 25s 177ms/step - loss: 0.3469 - accuracy: 0.8659 - val_loss: 0.4657 - val_accuracy: 0.8390
# Epoch 48/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3594 - accuracy: 0.8606
# Epoch 48: val_loss did not improve from 0.40730
# 142/142 [==============================] - 25s 178ms/step - loss: 0.3594 - accuracy: 0.8606 - val_loss: 0.4358 - val_accuracy: 0.8405
# Epoch 49/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3460 - accuracy: 0.8666
# Epoch 49: val_loss did not improve from 0.40730
# 142/142 [==============================] - 25s 176ms/step - loss: 0.3460 - accuracy: 0.8666 - val_loss: 0.4073 - val_accuracy: 0.8512
# Epoch 50/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3475 - accuracy: 0.8633
# Epoch 50: val_loss did not improve from 0.40730
# 142/142 [==============================] - 27s 188ms/step - loss: 0.3475 - accuracy: 0.8633 - val_loss: 0.4758 - val_accuracy: 0.8512
# Epoch 51/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3356 - accuracy: 0.8695
# Epoch 51: val_loss did not improve from 0.40730
# 142/142 [==============================] - 25s 176ms/step - loss: 0.3356 - accuracy: 0.8695 - val_loss: 0.4546 - val_accuracy: 0.8405
# Epoch 52/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.8531
# Epoch 52: val_loss did not improve from 0.40730
# 142/142 [==============================] - 25s 177ms/step - loss: 0.3834 - accuracy: 0.8531 - val_loss: 0.4655 - val_accuracy: 0.8558
# Epoch 53/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3620 - accuracy: 0.8586
# Epoch 53: val_loss did not improve from 0.40730
# 142/142 [==============================] - 25s 177ms/step - loss: 0.3620 - accuracy: 0.8586 - val_loss: 0.4416 - val_accuracy: 0.8420
# 21/21 [==============================] - 4s 175ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.9592    0.7622    0.8494       185
# meningioma_tumor     0.7500    0.8663    0.8040       187
#         no_tumor     0.9010    0.9100    0.9055       100
#  pituitary_tumor     0.8989    0.9389    0.9185       180
#
#         accuracy                         0.8635       652
#        macro avg     0.8773    0.8693    0.8693       652
#     weighted avg     0.8736    0.8635    0.8640       652

# %% [markdown]
# # Fine Tuning

# %%
#load best model
best_model_path = os.path.join(models_path, 'VGG16/VGG16_128.h5')
best_model_name = 'VGG16_128'
model = load_model(best_model_path)

# %% [markdown]
# ## Unfreeze block5_conv3

# %%
# Scongela i pesi del modello base
model.trainable = True
base_model = model.get_layer('vgg16')
base_model.summary()
# set to trainable all layers from block5_conv2
set_trainable = False
for layer in base_model.layers:
    if layer.name == 'block5_conv3':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# Compila il modello
compile_model(model,"adam",1e-5)

# Addestra il modello
run_model(model,"VGG16", best_model_name + "_finetuned")

# Evaluate model
evaluate_model(model,test_generator, best_model_name + "_finetuned", "VGG16")

# %% [markdown]
# ## Unfreeze block5_conv2

# %%
# Scongela i pesi del modello base
model.trainable = True
base_model = model.get_layer('vgg16')
base_model.summary()
# set to trainable all layers from block5_conv2
set_trainable = False
for layer in base_model.layers:
    if layer.name == 'block5_conv2':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# Compila il modello
compile_model(model,"adam",1e-5)

# Addestra il modello
run_model(model,"VGG16", best_model_name + "_finetuned")

# Evaluate model
evaluate_model(model,test_generator, best_model_name + "_finetuned", "VGG16")

# %% [markdown]
# ## Unfreeze block5_conv1

# %%
# Scongela i pesi del modello base
model.trainable = True
base_model = model.get_layer('vgg16')
base_model.summary()
# set to trainable all layers from block5_conv2
set_trainable = False
for layer in base_model.layers:
    if layer.name == 'block5_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# Compila il modello
compile_model(model,"adam",1e-5)

# Addestra il modello
run_model(model,"VGG16", best_model_name + "_finetuned")

# Evaluate model
evaluate_model(model,test_generator, best_model_name + "_finetuned", "VGG16")

# %% [markdown]
# ## Unfreeze block4_conv1

# %%
# Scongela i pesi del modello base
model.trainable = True
base_model = model.get_layer('vgg16')
base_model.summary()
# set to trainable all layers from block4_conv1
set_trainable = False
for layer in base_model.layers:
    if layer.name == 'block4_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# Compila il modello
compile_model(model,"adam",1e-5)

# Addestra il modello
run_model(model,"VGG16", best_model_name + "_finetuned")

# Evaluate model
evaluate_model(model,test_generator, best_model_name + "_finetuned", "VGG16")

# %% [markdown]
# ## Unfreeze block3_conv1

# %%
# Scongela i pesi del modello base
model.trainable = True
base_model = model.get_layer('vgg16')
base_model.summary()
# set to trainable all layers from block4_conv1
set_trainable = False
for layer in base_model.layers:
    if layer.name == 'block3_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# Compila il modello
compile_model(model,"adam",1e-5)

# Addestra il modello
run_model(model,"VGG16", best_model_name + "_finetuned")

# Evaluate model
evaluate_model(model,test_generator, best_model_name + "_finetuned", "VGG16")
