# %% [markdown]
# ## Import Libraries

# %%
from google.colab import drive
import os
import shutil
import numpy as np
import random as rn
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications.inception_v3 import InceptionV3
import matplotlib.pyplot as plt
from sklearn import metrics
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import LabelBinarizer

from keras.applications import VGG16
from keras.models import Sequential ,load_model
from keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D

# %% [markdown]
# ## Google Drive connection

# %%
# mount drive 
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Utilities

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

from tensorflow.keras import backend as K
from itertools import cycle
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, roc_auc_score

dataset_path = "/content/drive/MyDrive/DiDonato_Giorgi"

# path about the preprocessed dataset
base_path = "/content/drive/MyDrive/DiDonato_Giorgi/Preprocessed/Unified"

# path about test, train and validation sets
test_path = "/content/drive/MyDrive/DiDonato_Giorgi/Preprocessed/CLAHE/Test"
val_path = "/content/drive/MyDrive/DiDonato_Giorgi/Preprocessed/CLAHE/Validation"
train_path = "/content/drive/MyDrive/DiDonato_Giorgi/Preprocessed/CLAHE/Train"

models_path = "/content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE"
cnn_results_path = os.path.join(models_path, 'CNN')
vgg16_results_path = os.path.join(models_path, 'VGG16')
resnet50_results_path = os.path.join(models_path, 'ResNet50')
inceptionv3_results_path = os.path.join(models_path, 'InceptionV3')
# actual_results_path = vgg16_results_path

def set_seed ():
	''' 
	set_seed is used to obtain reproducible results using keras during the development phase
	'''
	seed = 10
	# The below is necessary for reproducible results of certain Python hash-based operations.
	os.environ["PYTHONHASHSEED"]="0"
	# The below is necessary for starting Numpy generated random numbers in a well-defined initial state.
	np.random.seed(seed)
	# The below is necessary for starting core Python generated random numbers in a well-defined state.
	rn.seed(seed)
	# The below tf.random.set_seed will make x number generation in TensorFlow have a well-defined initial state.
	tf.random.set_seed(seed)     

# image size
image_size = 224
batch_size = 32

# create the generators for data augmentation with rescaling
data_generator = ImageDataGenerator(rescale=1.0/255.0)

# load train, test and validation sets
train_generator = data_generator.flow_from_directory(
    train_path,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = data_generator.flow_from_directory(
    test_path,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

val_generator = data_generator.flow_from_directory(
    val_path,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical'
)
     

def show_training_and_validation_performance(history,path):
	'''
	show_training_and_validation_performance is used to plot the performances during the training phase
	:param history: object in which are recorded all the events
	'''
	acc = history.history['accuracy']
	val_acc = history.history['val_accuracy']
	loss = history.history['loss']
	val_loss = history.history['val_loss']

	epochs = range(len(acc))

	plt.plot(epochs, acc, 'bo', label='Training accuracy')
	plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
	plt.title('Training and validation accuracy')
	plt.legend()

	plt.figure()

	plt.plot(epochs, loss, 'bo', label='Training loss')
	plt.plot(epochs, val_loss, 'b', label='Validation loss')
	plt.title('Training and validation loss')
	plt.legend()

	plt.savefig(path)

	plt.show()

def compile_model (model, optimizer='adam', learning_rate = 0.001):
	'''
	compile_model is used to compile the current model
	:param model: model to compile
	:param optimizer: optimizer to be used
	:param learning_rate: learning rate parameter for the optimizer
	'''
	if optimizer == 'adam':
		model.compile(loss="categorical_crossentropy",
		optimizer=optimizers.Adam(learning_rate=learning_rate),
		metrics=["accuracy"])
	elif optimizer == 'rmsprop':
		model.compile(loss="categorical_crossentropy",
					optimizer = optimizers.RMSprop(learning_rate=learning_rate),
					metrics=['accuracy'])
	model.summary()

def run_model (model, type, model_name, epochs = 100, patience=5, monitor='val_loss'):
	'''
	run_model is used to run the current mode
	:param model: model to run
	:param model_name: name given to save the model
	:param type: type of model, CNN, VGG16, ResNet50, InceptionV3
	:param epochs: how many epochs to do
	:param patience: patience value for Early Stopping
	:param monitor: what to monitor for Early Stopping and Model Checkpoint
	'''
	# local save path for the models
	save_path = os.path.join(models_path, type + '/' + model_name + '.h5') 
	callbacks_list = [
					keras.callbacks.EarlyStopping(monitor=monitor, patience=patience),
					keras.callbacks.ModelCheckpoint(
						filepath = save_path,
						monitor=monitor,
						verbose=1,
						save_best_only=True)
					]
	history = model.fit(train_generator,
						epochs=epochs,
						validation_data=val_generator,
						callbacks=callbacks_list)
	# save on Drive only the best model
	show_training_and_validation_performance(history,os.path.join(models_path, type + '/' + model_name + '_validation.png'))

def plot_roc_curve(y_true, y_pred, n_classes, class_labels, model_name, type):

    # label conversion to binary format
    lb = LabelBinarizer()
    y_true_binary = lb.fit_transform(y_true)

    # compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(n_classes):
        fpr[i], tpr[i], _ = metrics.roc_curve(y_true_binary[:, i], y_pred[:, i])
        roc_auc[i] = metrics.auc(fpr[i], tpr[i])

    plt.figure()
    colors = ['blue', 'red', 'green', 'orange'] 

    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, label='ROC curve {0} ({1:0.2f}%)'.format(class_labels[i], roc_auc[i]*100))

    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve')
    plt.legend(loc="lower right")
    plt.savefig(os.path.join(models_path, type + '/' + model_name + '_ROC.png'))
    plt.show()

def evaluate_model (model, test_generator, model_name, type):
	'''
	evaluate_model is used to plot some statistics about the performance on the test set
	:param model: model to consider
	'''
	labels_d= ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

	# get predictions
	y_score = model.predict(test_generator)
	# convert predictions to classes
	y_pred = np.argmax(y_score, axis=-1)
	# get true classes
	y_true = test_generator.classes
	# extract class labels
	class_labels = list(test_generator.class_indices.keys())
	
	print("Classification report: ")
	# create and show classification report
	print(metrics.classification_report(y_true, y_pred, target_names=class_labels,digits = 4))
	# save classification report
	with open(os.path.join(models_path, type + '/' + model_name + '_classification_report.txt'), 'w') as f:
		f.write(metrics.classification_report(y_true, y_pred, target_names=class_labels,digits = 4))

	# create and show confusion matrix	
	cm = confusion_matrix(y_true, y_pred)	
	disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
	disp.plot(xticks_rotation=45)
	
	# save confusion matrix
	plt.savefig(os.path.join(models_path, type, model_name + '_confusion_matrix.png'), bbox_inches='tight', pad_inches=0.1)
	plt.show()

	plot_roc_curve(y_true, y_score, 4, class_labels, model_name, type)

def get_index_by_layer_name(model, layer_name):
  '''
  get_index_by_layer_name is used to retrieve the index of a specific layer
  :param model: model to check
  :param layer_name: name of the layer we want to get the index of
  :return: the index of the layer named as defined in layer_name
  '''
  for index, layer in enumerate(model.layers):
      if layer.name == layer_name:
          return index 

def clear(model):
	del model
	K.clear_session() 

set_seed ()
# Out:
# Found 4520 images belonging to 4 classes.
# Found 652 images belonging to 4 classes.
# Found 652 images belonging to 4 classes.

# %% [markdown]
# ## Load Inception V3

# %%
# load the pretrained model without the top layer 
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 111, 111, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 111, 111, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 109, 109, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 109, 109, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 109, 109, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 109, 109, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 109, 109, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 109, 109, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 54, 54, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 54, 54, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 54, 54, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 54, 54, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 52, 52, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 52, 52, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 52, 52, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 25, 25, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 25, 25, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 25, 25, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 25, 25, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 25, 25, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 25, 25, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 25, 25, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 25, 25, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 25, 25, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 25, 25, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 25, 25, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 25, 25, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 25, 25, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 25, 25, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 25, 25, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 25, 25, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 25, 25, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 25, 25, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 25, 25, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 25, 25, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 25, 25, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 25, 25, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 25, 25, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 25, 25, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 25, 25, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 25, 25, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 25, 25, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 25, 25, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 25, 25, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 25, 25, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 25, 25, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 25, 25, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 25, 25, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 25, 25, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 25, 25, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 25, 25, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 25, 25, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 12, 12, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 12, 12, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 12, 12, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 12, 12, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 12, 12, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 12, 12, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 12, 12, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 12, 12, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 12, 12, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 12, 12, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 12, 12, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 12, 12, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 12, 12, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 12, 12, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 12, 12, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 12, 12, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 12, 12, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 12, 12, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 12, 12, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 12, 12, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 12, 12, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 12, 12, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 12, 12, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 12, 12, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 12, 12, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 12, 12, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 12, 12, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 12, 12, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 12, 12, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 12, 12, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 12, 12, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 12, 12, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 12, 12, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 12, 12, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 12, 12, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 12, 12, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 12, 12, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 12, 12, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 12, 12, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 12, 12, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_58[0][0]']
# ...
#  mixed8 (Concatenate)           (None, 5, 5, 1280)   0           ['activation_71[0][0]',
#                                                                   'activation_75[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 5, 5, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 5, 5, 448)   1344        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 5, 5, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 5, 5, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 5, 5, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 5, 5, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 5, 5, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 5, 5, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 5, 5, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 5, 5, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 5, 5, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 5, 5, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 5, 5, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 5, 5, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 5, 5, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 5, 5, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 5, 5, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 5, 5, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 5, 5, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 5, 5, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %% [markdown]
# # Feature extraction

# %% [markdown]
# ## Experiment 1
#
# Start using Flatten layer and one dense layer with 128 neurons

# %%
model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(4, activation='softmax')) #4 classi di output

# freeze the layers of the pretrained model
for layer in base_model.layers:
    layer.trainable = False

# compile the model
compile_model(model)

# run the model
run_model(model, 'InceptionV3', "InceptionV3_128_clahe")

# evaluate model
evaluate_model(model,test_generator, 'InceptionV3_128_clahe', "InceptionV3")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 128)               6553728
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 28,357,028
# Trainable params: 6,554,244
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 3.4203 - accuracy: 0.6715
# Epoch 1: val_loss improved from inf to 0.50578, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_clahe.h5
# 142/142 [==============================] - 817s 6s/step - loss: 3.4203 - accuracy: 0.6715 - val_loss: 0.5058 - val_accuracy: 0.8221
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.8303
# Epoch 2: val_loss did not improve from 0.50578
# 142/142 [==============================] - 25s 178ms/step - loss: 0.4659 - accuracy: 0.8303 - val_loss: 0.5416 - val_accuracy: 0.8344
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9301
# Epoch 3: val_loss improved from 0.50578 to 0.47084, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_clahe.h5
# 142/142 [==============================] - 31s 216ms/step - loss: 0.1997 - accuracy: 0.9301 - val_loss: 0.4708 - val_accuracy: 0.8436
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9635
# Epoch 4: val_loss improved from 0.47084 to 0.42430, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_clahe.h5
# 142/142 [==============================] - 28s 192ms/step - loss: 0.1126 - accuracy: 0.9635 - val_loss: 0.4243 - val_accuracy: 0.8712
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9737
# Epoch 5: val_loss did not improve from 0.42430
# 142/142 [==============================] - 25s 177ms/step - loss: 0.0806 - accuracy: 0.9737 - val_loss: 0.4346 - val_accuracy: 0.8589
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9883
# Epoch 6: val_loss did not improve from 0.42430
# 142/142 [==============================] - 26s 186ms/step - loss: 0.0443 - accuracy: 0.9883 - val_loss: 0.4937 - val_accuracy: 0.8512
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9993
# Epoch 7: val_loss did not improve from 0.42430
# 142/142 [==============================] - 27s 186ms/step - loss: 0.0134 - accuracy: 0.9993 - val_loss: 0.4456 - val_accuracy: 0.8804
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 8: val_loss did not improve from 0.42430
# 142/142 [==============================] - 25s 173ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.4440 - val_accuracy: 0.8773
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 9: val_loss did not improve from 0.42430
# 142/142 [==============================] - 24s 167ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4337 - val_accuracy: 0.8773
# 21/21 [==============================] - 141s 7s/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.8833    0.8595    0.8712       185
# meningioma_tumor     0.8223    0.8663    0.8438       187
#         no_tumor     0.9394    0.9300    0.9347       100
#  pituitary_tumor     0.9602    0.9389    0.9494       180
#
#         accuracy                         0.8942       652
#        macro avg     0.9013    0.8987    0.8998       652
#     weighted avg     0.8957    0.8942    0.8947       652

# %% [markdown]
# ## Experiment 2
# From previous experiment we notice an overfitting scenario, try to resolve this decreasing the learning rate value to 1e-5.

# %%
model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(4, activation='softmax'))

# freeze the layers of the pretrained model
for layer in base_model.layers:
    layer.trainable = False

# compile the model
compile_model(model, learning_rate=1e-5)

# run the model
run_model(model, 'InceptionV3', "InceptionV3_128_lr_clahe")

# evaluate model
evaluate_model(model,test_generator, 'InceptionV3_128_lr_clahe', "InceptionV3")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_2 (Dense)             (None, 128)               6553728
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 28,357,028
# Trainable params: 6,554,244
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 0.8198 - accuracy: 0.6673
# Epoch 1: val_loss improved from inf to 0.59672, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_clahe.h5
# 142/142 [==============================] - 32s 183ms/step - loss: 0.8198 - accuracy: 0.6673 - val_loss: 0.5967 - val_accuracy: 0.7485
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4227 - accuracy: 0.8493
# Epoch 2: val_loss improved from 0.59672 to 0.59309, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_clahe.h5
# 142/142 [==============================] - 30s 213ms/step - loss: 0.4227 - accuracy: 0.8493 - val_loss: 0.5931 - val_accuracy: 0.7991
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2722 - accuracy: 0.9162
# Epoch 3: val_loss improved from 0.59309 to 0.42895, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_clahe.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.2722 - accuracy: 0.9162 - val_loss: 0.4290 - val_accuracy: 0.8359
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1925 - accuracy: 0.9487
# Epoch 4: val_loss improved from 0.42895 to 0.39473, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_clahe.h5
# 142/142 [==============================] - 30s 214ms/step - loss: 0.1925 - accuracy: 0.9487 - val_loss: 0.3947 - val_accuracy: 0.8543
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9772
# Epoch 5: val_loss improved from 0.39473 to 0.37003, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_clahe.h5
# 142/142 [==============================] - 28s 191ms/step - loss: 0.1269 - accuracy: 0.9772 - val_loss: 0.3700 - val_accuracy: 0.8574
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9907
# Epoch 6: val_loss improved from 0.37003 to 0.36652, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_clahe.h5
# 142/142 [==============================] - 28s 195ms/step - loss: 0.0887 - accuracy: 0.9907 - val_loss: 0.3665 - val_accuracy: 0.8635
# Epoch 7/100
# 141/142 [============================>.] - ETA: 0s - loss: 0.0640 - accuracy: 0.9971
# Epoch 7: val_loss improved from 0.36652 to 0.34631, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_clahe.h5
# 142/142 [==============================] - 28s 193ms/step - loss: 0.0641 - accuracy: 0.9971 - val_loss: 0.3463 - val_accuracy: 0.8604
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9993
# Epoch 8: val_loss improved from 0.34631 to 0.34263, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_clahe.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.0497 - accuracy: 0.9993 - val_loss: 0.3426 - val_accuracy: 0.8696
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 1.0000
# Epoch 9: val_loss did not improve from 0.34263
# 142/142 [==============================] - 25s 178ms/step - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.3647 - val_accuracy: 0.8650
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9998
# Epoch 10: val_loss did not improve from 0.34263
# 142/142 [==============================] - 25s 175ms/step - loss: 0.0309 - accuracy: 0.9998 - val_loss: 0.3474 - val_accuracy: 0.8712
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 0.34263
# 142/142 [==============================] - 26s 182ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.3464 - val_accuracy: 0.8666
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.0000
# Epoch 12: val_loss improved from 0.34263 to 0.34242, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_clahe.h5
# 142/142 [==============================] - 26s 180ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.3424 - val_accuracy: 0.8650
# Epoch 13/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 1.0000
# Epoch 13: val_loss did not improve from 0.34242
# 142/142 [==============================] - 26s 186ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.3512 - val_accuracy: 0.8712
# Epoch 14/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 1.0000
# Epoch 14: val_loss did not improve from 0.34242
# 142/142 [==============================] - 27s 188ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.3526 - val_accuracy: 0.8834
# Epoch 15/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 0.34242
# 142/142 [==============================] - 26s 182ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.3526 - val_accuracy: 0.8742
# Epoch 16/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.34242
# 142/142 [==============================] - 26s 184ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.3531 - val_accuracy: 0.8727
# Epoch 17/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.34242
# 142/142 [==============================] - 24s 167ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.3520 - val_accuracy: 0.8758
# 21/21 [==============================] - 4s 138ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.8729    0.8541    0.8634       185
# meningioma_tumor     0.8404    0.8449    0.8427       187
#         no_tumor     0.9208    0.9300    0.9254       100
#  pituitary_tumor     0.9286    0.9389    0.9337       180
#
#         accuracy                         0.8865       652
#        macro avg     0.8907    0.8920    0.8913       652
#     weighted avg     0.8863    0.8865    0.8864       652

# %% [markdown]
# ## Experiment 3
#
# We achieved a good result but the validation loss is still high, let's try to use the GlobalAveragePooling2D instead of Flatten

# %%
model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(128, activation='relu'))
model.add(Dense(4, activation='softmax'))

# freeze the layers of the pretrained model
for layer in base_model.layers:
    layer.trainable = False

# compile the model
compile_model(model, learning_rate=1e-5)

# run the model
run_model(model, 'InceptionV3', "InceptionV3_128_gap_clahe")

# evaluate model
evaluate_model(model,test_generator, 'InceptionV3_128_gap_clahe', "InceptionV3")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 128)               262272
#
#  dense_5 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 22,065,572
# Trainable params: 262,788
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.3450 - accuracy: 0.3763
# Epoch 1: val_loss improved from inf to 1.19863, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 32s 188ms/step - loss: 1.3450 - accuracy: 0.3763 - val_loss: 1.1986 - val_accuracy: 0.4586
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 1.1234 - accuracy: 0.5177
# Epoch 2: val_loss improved from 1.19863 to 1.03137, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 1.1234 - accuracy: 0.5177 - val_loss: 1.0314 - val_accuracy: 0.5890
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.9886 - accuracy: 0.6093
# Epoch 3: val_loss improved from 1.03137 to 0.92730, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 182ms/step - loss: 0.9886 - accuracy: 0.6093 - val_loss: 0.9273 - val_accuracy: 0.6457
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.8941 - accuracy: 0.6593
# Epoch 4: val_loss improved from 0.92730 to 0.86942, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 185ms/step - loss: 0.8941 - accuracy: 0.6593 - val_loss: 0.8694 - val_accuracy: 0.6672
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.8260 - accuracy: 0.6938
# Epoch 5: val_loss improved from 0.86942 to 0.79283, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 190ms/step - loss: 0.8260 - accuracy: 0.6938 - val_loss: 0.7928 - val_accuracy: 0.7009
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.7705 - accuracy: 0.7219
# Epoch 6: val_loss improved from 0.79283 to 0.75337, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.7705 - accuracy: 0.7219 - val_loss: 0.7534 - val_accuracy: 0.7163
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.7278 - accuracy: 0.7400
# Epoch 7: val_loss improved from 0.75337 to 0.72197, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 184ms/step - loss: 0.7278 - accuracy: 0.7400 - val_loss: 0.7220 - val_accuracy: 0.7255
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6915 - accuracy: 0.7580
# Epoch 8: val_loss improved from 0.72197 to 0.69670, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 197ms/step - loss: 0.6915 - accuracy: 0.7580 - val_loss: 0.6967 - val_accuracy: 0.7377
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6626 - accuracy: 0.7659
# Epoch 9: val_loss improved from 0.69670 to 0.67987, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 200ms/step - loss: 0.6626 - accuracy: 0.7659 - val_loss: 0.6799 - val_accuracy: 0.7500
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6376 - accuracy: 0.7748
# Epoch 10: val_loss improved from 0.67987 to 0.66539, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 190ms/step - loss: 0.6376 - accuracy: 0.7748 - val_loss: 0.6654 - val_accuracy: 0.7454
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6170 - accuracy: 0.7832
# Epoch 11: val_loss improved from 0.66539 to 0.65063, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 195ms/step - loss: 0.6170 - accuracy: 0.7832 - val_loss: 0.6506 - val_accuracy: 0.7577
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5966 - accuracy: 0.7894
# Epoch 12: val_loss improved from 0.65063 to 0.63646, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 196ms/step - loss: 0.5966 - accuracy: 0.7894 - val_loss: 0.6365 - val_accuracy: 0.7561
# Epoch 13/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5801 - accuracy: 0.7996
# Epoch 13: val_loss improved from 0.63646 to 0.62307, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 191ms/step - loss: 0.5801 - accuracy: 0.7996 - val_loss: 0.6231 - val_accuracy: 0.7669
# Epoch 14/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5648 - accuracy: 0.8031
# Epoch 14: val_loss improved from 0.62307 to 0.61177, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 29s 202ms/step - loss: 0.5648 - accuracy: 0.8031 - val_loss: 0.6118 - val_accuracy: 0.7745
# Epoch 15/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5496 - accuracy: 0.8102
# Epoch 15: val_loss improved from 0.61177 to 0.60597, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 200ms/step - loss: 0.5496 - accuracy: 0.8102 - val_loss: 0.6060 - val_accuracy: 0.7684
# Epoch 16/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5374 - accuracy: 0.8173
# Epoch 16: val_loss improved from 0.60597 to 0.59521, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 190ms/step - loss: 0.5374 - accuracy: 0.8173 - val_loss: 0.5952 - val_accuracy: 0.7715
# Epoch 17/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5257 - accuracy: 0.8217
# Epoch 17: val_loss improved from 0.59521 to 0.58605, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.5257 - accuracy: 0.8217 - val_loss: 0.5861 - val_accuracy: 0.7730
# Epoch 18/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5142 - accuracy: 0.8268
# Epoch 18: val_loss improved from 0.58605 to 0.57749, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 29s 203ms/step - loss: 0.5142 - accuracy: 0.8268 - val_loss: 0.5775 - val_accuracy: 0.7745
# Epoch 19/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5041 - accuracy: 0.8303
# Epoch 19: val_loss improved from 0.57749 to 0.57692, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 191ms/step - loss: 0.5041 - accuracy: 0.8303 - val_loss: 0.5769 - val_accuracy: 0.7776
# Epoch 20/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4938 - accuracy: 0.8392
# Epoch 20: val_loss improved from 0.57692 to 0.56324, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 186ms/step - loss: 0.4938 - accuracy: 0.8392 - val_loss: 0.5632 - val_accuracy: 0.7868
# Epoch 21/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4837 - accuracy: 0.8387
# Epoch 21: val_loss improved from 0.56324 to 0.55350, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 185ms/step - loss: 0.4837 - accuracy: 0.8387 - val_loss: 0.5535 - val_accuracy: 0.7853
# Epoch 22/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4757 - accuracy: 0.8398
# Epoch 22: val_loss improved from 0.55350 to 0.55075, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 179ms/step - loss: 0.4757 - accuracy: 0.8398 - val_loss: 0.5507 - val_accuracy: 0.7929
# Epoch 23/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4677 - accuracy: 0.8451
# Epoch 23: val_loss improved from 0.55075 to 0.54691, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 188ms/step - loss: 0.4677 - accuracy: 0.8451 - val_loss: 0.5469 - val_accuracy: 0.7914
# Epoch 24/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4589 - accuracy: 0.8482
# Epoch 24: val_loss improved from 0.54691 to 0.54645, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 182ms/step - loss: 0.4589 - accuracy: 0.8482 - val_loss: 0.5464 - val_accuracy: 0.7960
# Epoch 25/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4509 - accuracy: 0.8518
# Epoch 25: val_loss improved from 0.54645 to 0.53928, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 184ms/step - loss: 0.4509 - accuracy: 0.8518 - val_loss: 0.5393 - val_accuracy: 0.7914
# Epoch 26/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4434 - accuracy: 0.8546
# Epoch 26: val_loss improved from 0.53928 to 0.53180, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.4434 - accuracy: 0.8546 - val_loss: 0.5318 - val_accuracy: 0.7960
# Epoch 27/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4375 - accuracy: 0.8575
# Epoch 27: val_loss improved from 0.53180 to 0.53020, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 29s 200ms/step - loss: 0.4375 - accuracy: 0.8575 - val_loss: 0.5302 - val_accuracy: 0.7975
# Epoch 28/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4299 - accuracy: 0.8604
# Epoch 28: val_loss improved from 0.53020 to 0.52756, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 182ms/step - loss: 0.4299 - accuracy: 0.8604 - val_loss: 0.5276 - val_accuracy: 0.7991
# Epoch 29/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4241 - accuracy: 0.8577
# Epoch 29: val_loss did not improve from 0.52756
# 142/142 [==============================] - 25s 172ms/step - loss: 0.4241 - accuracy: 0.8577 - val_loss: 0.5293 - val_accuracy: 0.7960
# Epoch 30/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4175 - accuracy: 0.8624
# Epoch 30: val_loss improved from 0.52756 to 0.51779, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 25s 178ms/step - loss: 0.4175 - accuracy: 0.8624 - val_loss: 0.5178 - val_accuracy: 0.7991
# Epoch 31/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4121 - accuracy: 0.8650
# Epoch 31: val_loss did not improve from 0.51779
# 142/142 [==============================] - 27s 188ms/step - loss: 0.4121 - accuracy: 0.8650 - val_loss: 0.5182 - val_accuracy: 0.8052
# Epoch 32/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4054 - accuracy: 0.8664
# Epoch 32: val_loss improved from 0.51779 to 0.51007, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 194ms/step - loss: 0.4054 - accuracy: 0.8664 - val_loss: 0.5101 - val_accuracy: 0.8037
# Epoch 33/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3994 - accuracy: 0.8697
# Epoch 33: val_loss improved from 0.51007 to 0.50574, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 197ms/step - loss: 0.3994 - accuracy: 0.8697 - val_loss: 0.5057 - val_accuracy: 0.7991
# Epoch 34/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3939 - accuracy: 0.8737
# Epoch 34: val_loss did not improve from 0.50574
# 142/142 [==============================] - 24s 172ms/step - loss: 0.3939 - accuracy: 0.8737 - val_loss: 0.5083 - val_accuracy: 0.8129
# Epoch 35/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3884 - accuracy: 0.8754
# Epoch 35: val_loss improved from 0.50574 to 0.50401, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 180ms/step - loss: 0.3884 - accuracy: 0.8754 - val_loss: 0.5040 - val_accuracy: 0.8129
# Epoch 36/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3839 - accuracy: 0.8765
# Epoch 36: val_loss improved from 0.50401 to 0.50081, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 181ms/step - loss: 0.3839 - accuracy: 0.8765 - val_loss: 0.5008 - val_accuracy: 0.8083
# Epoch 37/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3786 - accuracy: 0.8785
# Epoch 37: val_loss improved from 0.50081 to 0.49613, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 184ms/step - loss: 0.3786 - accuracy: 0.8785 - val_loss: 0.4961 - val_accuracy: 0.8083
# Epoch 38/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3734 - accuracy: 0.8783
# Epoch 38: val_loss improved from 0.49613 to 0.49472, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.3734 - accuracy: 0.8783 - val_loss: 0.4947 - val_accuracy: 0.8083
# Epoch 39/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8825
# Epoch 39: val_loss improved from 0.49472 to 0.49284, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 186ms/step - loss: 0.3684 - accuracy: 0.8825 - val_loss: 0.4928 - val_accuracy: 0.8190
# Epoch 40/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3643 - accuracy: 0.8843
# Epoch 40: val_loss improved from 0.49284 to 0.48764, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 184ms/step - loss: 0.3643 - accuracy: 0.8843 - val_loss: 0.4876 - val_accuracy: 0.8160
# Epoch 41/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3592 - accuracy: 0.8845
# Epoch 41: val_loss did not improve from 0.48764
# 142/142 [==============================] - 25s 174ms/step - loss: 0.3592 - accuracy: 0.8845 - val_loss: 0.4880 - val_accuracy: 0.8129
# Epoch 42/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3551 - accuracy: 0.8874
# Epoch 42: val_loss improved from 0.48764 to 0.48565, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 194ms/step - loss: 0.3551 - accuracy: 0.8874 - val_loss: 0.4857 - val_accuracy: 0.8221
# Epoch 43/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3504 - accuracy: 0.8878
# Epoch 43: val_loss did not improve from 0.48565
# 142/142 [==============================] - 25s 174ms/step - loss: 0.3504 - accuracy: 0.8878 - val_loss: 0.4879 - val_accuracy: 0.8252
# Epoch 44/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8912
# Epoch 44: val_loss improved from 0.48565 to 0.47862, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.3463 - accuracy: 0.8912 - val_loss: 0.4786 - val_accuracy: 0.8160
# Epoch 45/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3425 - accuracy: 0.8931
# Epoch 45: val_loss did not improve from 0.47862
# 142/142 [==============================] - 24s 168ms/step - loss: 0.3425 - accuracy: 0.8931 - val_loss: 0.4827 - val_accuracy: 0.8144
# Epoch 46/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3383 - accuracy: 0.8954
# Epoch 46: val_loss did not improve from 0.47862
# 142/142 [==============================] - 24s 172ms/step - loss: 0.3383 - accuracy: 0.8954 - val_loss: 0.4802 - val_accuracy: 0.8160
# Epoch 47/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3338 - accuracy: 0.8989
# Epoch 47: val_loss improved from 0.47862 to 0.47083, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 184ms/step - loss: 0.3338 - accuracy: 0.8989 - val_loss: 0.4708 - val_accuracy: 0.8221
# Epoch 48/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3306 - accuracy: 0.9004
# Epoch 48: val_loss did not improve from 0.47083
# 142/142 [==============================] - 25s 177ms/step - loss: 0.3306 - accuracy: 0.9004 - val_loss: 0.4728 - val_accuracy: 0.8206
# Epoch 49/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3261 - accuracy: 0.9009
# Epoch 49: val_loss improved from 0.47083 to 0.46949, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 190ms/step - loss: 0.3261 - accuracy: 0.9009 - val_loss: 0.4695 - val_accuracy: 0.8221
# Epoch 50/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3223 - accuracy: 0.9055
# Epoch 50: val_loss improved from 0.46949 to 0.46560, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 193ms/step - loss: 0.3223 - accuracy: 0.9055 - val_loss: 0.4656 - val_accuracy: 0.8190
# Epoch 51/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.9046
# Epoch 51: val_loss did not improve from 0.46560
# 142/142 [==============================] - 25s 173ms/step - loss: 0.3188 - accuracy: 0.9046 - val_loss: 0.4660 - val_accuracy: 0.8236
# Epoch 52/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.9046
# Epoch 52: val_loss improved from 0.46560 to 0.46507, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 180ms/step - loss: 0.3151 - accuracy: 0.9046 - val_loss: 0.4651 - val_accuracy: 0.8236
# Epoch 53/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3116 - accuracy: 0.9046
# Epoch 53: val_loss improved from 0.46507 to 0.46327, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 189ms/step - loss: 0.3116 - accuracy: 0.9046 - val_loss: 0.4633 - val_accuracy: 0.8252
# Epoch 54/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.9066
# Epoch 54: val_loss did not improve from 0.46327
# 142/142 [==============================] - 26s 184ms/step - loss: 0.3099 - accuracy: 0.9066 - val_loss: 0.4634 - val_accuracy: 0.8206
# Epoch 55/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.9119
# Epoch 55: val_loss improved from 0.46327 to 0.46242, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.3052 - accuracy: 0.9119 - val_loss: 0.4624 - val_accuracy: 0.8267
# Epoch 56/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3016 - accuracy: 0.9104
# Epoch 56: val_loss improved from 0.46242 to 0.45625, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 181ms/step - loss: 0.3016 - accuracy: 0.9104 - val_loss: 0.4562 - val_accuracy: 0.8282
# Epoch 57/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.9122
# Epoch 57: val_loss improved from 0.45625 to 0.45612, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 192ms/step - loss: 0.2985 - accuracy: 0.9122 - val_loss: 0.4561 - val_accuracy: 0.8298
# Epoch 58/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2950 - accuracy: 0.9150
# Epoch 58: val_loss improved from 0.45612 to 0.45425, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 194ms/step - loss: 0.2950 - accuracy: 0.9150 - val_loss: 0.4543 - val_accuracy: 0.8298
# Epoch 59/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2917 - accuracy: 0.9157
# Epoch 59: val_loss improved from 0.45425 to 0.45338, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.2917 - accuracy: 0.9157 - val_loss: 0.4534 - val_accuracy: 0.8298
# Epoch 60/100
# 141/142 [============================>.] - ETA: 0s - loss: 0.2889 - accuracy: 0.9167
# Epoch 60: val_loss did not improve from 0.45338
# 142/142 [==============================] - 26s 185ms/step - loss: 0.2888 - accuracy: 0.9168 - val_loss: 0.4544 - val_accuracy: 0.8298
# Epoch 61/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2860 - accuracy: 0.9190
# Epoch 61: val_loss improved from 0.45338 to 0.45077, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 193ms/step - loss: 0.2860 - accuracy: 0.9190 - val_loss: 0.4508 - val_accuracy: 0.8313
# Epoch 62/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.9199
# Epoch 62: val_loss did not improve from 0.45077
# 142/142 [==============================] - 25s 172ms/step - loss: 0.2826 - accuracy: 0.9199 - val_loss: 0.4527 - val_accuracy: 0.8236
# Epoch 63/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.9221
# Epoch 63: val_loss improved from 0.45077 to 0.44739, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 180ms/step - loss: 0.2796 - accuracy: 0.9221 - val_loss: 0.4474 - val_accuracy: 0.8359
# Epoch 64/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9204
# Epoch 64: val_loss did not improve from 0.44739
# 142/142 [==============================] - 26s 183ms/step - loss: 0.2767 - accuracy: 0.9204 - val_loss: 0.4476 - val_accuracy: 0.8328
# Epoch 65/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2742 - accuracy: 0.9204
# Epoch 65: val_loss did not improve from 0.44739
# 142/142 [==============================] - 25s 174ms/step - loss: 0.2742 - accuracy: 0.9204 - val_loss: 0.4476 - val_accuracy: 0.8282
# Epoch 66/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2710 - accuracy: 0.9215
# Epoch 66: val_loss improved from 0.44739 to 0.44473, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 182ms/step - loss: 0.2710 - accuracy: 0.9215 - val_loss: 0.4447 - val_accuracy: 0.8328
# Epoch 67/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.9250
# Epoch 67: val_loss did not improve from 0.44473
# 142/142 [==============================] - 25s 176ms/step - loss: 0.2681 - accuracy: 0.9250 - val_loss: 0.4448 - val_accuracy: 0.8344
# Epoch 68/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.9252
# Epoch 68: val_loss improved from 0.44473 to 0.44050, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 180ms/step - loss: 0.2657 - accuracy: 0.9252 - val_loss: 0.4405 - val_accuracy: 0.8328
# Epoch 69/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2629 - accuracy: 0.9263
# Epoch 69: val_loss improved from 0.44050 to 0.44013, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 28s 196ms/step - loss: 0.2629 - accuracy: 0.9263 - val_loss: 0.4401 - val_accuracy: 0.8344
# Epoch 70/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2601 - accuracy: 0.9277
# Epoch 70: val_loss did not improve from 0.44013
# 142/142 [==============================] - 26s 184ms/step - loss: 0.2601 - accuracy: 0.9277 - val_loss: 0.4410 - val_accuracy: 0.8313
# Epoch 71/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.9294
# Epoch 71: val_loss improved from 0.44013 to 0.43653, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 180ms/step - loss: 0.2572 - accuracy: 0.9294 - val_loss: 0.4365 - val_accuracy: 0.8390
# Epoch 72/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2546 - accuracy: 0.9294
# Epoch 72: val_loss did not improve from 0.43653
# 142/142 [==============================] - 25s 174ms/step - loss: 0.2546 - accuracy: 0.9294 - val_loss: 0.4393 - val_accuracy: 0.8328
# Epoch 73/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2523 - accuracy: 0.9314
# Epoch 73: val_loss improved from 0.43653 to 0.43544, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 25s 177ms/step - loss: 0.2523 - accuracy: 0.9314 - val_loss: 0.4354 - val_accuracy: 0.8344
# Epoch 74/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.9312
# Epoch 74: val_loss did not improve from 0.43544
# 142/142 [==============================] - 25s 175ms/step - loss: 0.2496 - accuracy: 0.9312 - val_loss: 0.4361 - val_accuracy: 0.8298
# Epoch 75/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2476 - accuracy: 0.9308
# Epoch 75: val_loss improved from 0.43544 to 0.43347, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 182ms/step - loss: 0.2476 - accuracy: 0.9308 - val_loss: 0.4335 - val_accuracy: 0.8405
# Epoch 76/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2446 - accuracy: 0.9338
# Epoch 76: val_loss did not improve from 0.43347
# 142/142 [==============================] - 25s 176ms/step - loss: 0.2446 - accuracy: 0.9338 - val_loss: 0.4357 - val_accuracy: 0.8374
# Epoch 77/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.9327
# Epoch 77: val_loss did not improve from 0.43347
# 142/142 [==============================] - 24s 172ms/step - loss: 0.2423 - accuracy: 0.9327 - val_loss: 0.4356 - val_accuracy: 0.8374
# Epoch 78/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2402 - accuracy: 0.9363
# Epoch 78: val_loss improved from 0.43347 to 0.43291, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 181ms/step - loss: 0.2402 - accuracy: 0.9363 - val_loss: 0.4329 - val_accuracy: 0.8344
# Epoch 79/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.9378
# Epoch 79: val_loss improved from 0.43291 to 0.43191, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 184ms/step - loss: 0.2379 - accuracy: 0.9378 - val_loss: 0.4319 - val_accuracy: 0.8374
# Epoch 80/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9354
# Epoch 80: val_loss improved from 0.43191 to 0.42678, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.2354 - accuracy: 0.9354 - val_loss: 0.4268 - val_accuracy: 0.8405
# Epoch 81/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.9365
# Epoch 81: val_loss did not improve from 0.42678
# 142/142 [==============================] - 24s 170ms/step - loss: 0.2330 - accuracy: 0.9365 - val_loss: 0.4276 - val_accuracy: 0.8451
# Epoch 82/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2306 - accuracy: 0.9369
# Epoch 82: val_loss did not improve from 0.42678
# 142/142 [==============================] - 24s 169ms/step - loss: 0.2306 - accuracy: 0.9369 - val_loss: 0.4271 - val_accuracy: 0.8390
# Epoch 83/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2287 - accuracy: 0.9412
# Epoch 83: val_loss improved from 0.42678 to 0.42441, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 29s 201ms/step - loss: 0.2287 - accuracy: 0.9412 - val_loss: 0.4244 - val_accuracy: 0.8451
# Epoch 84/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9416
# Epoch 84: val_loss did not improve from 0.42441
# 142/142 [==============================] - 25s 175ms/step - loss: 0.2248 - accuracy: 0.9416 - val_loss: 0.4275 - val_accuracy: 0.8405
# Epoch 85/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2243 - accuracy: 0.9400
# Epoch 85: val_loss did not improve from 0.42441
# 142/142 [==============================] - 24s 172ms/step - loss: 0.2243 - accuracy: 0.9400 - val_loss: 0.4290 - val_accuracy: 0.8420
# Epoch 86/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2211 - accuracy: 0.9429
# Epoch 86: val_loss did not improve from 0.42441
# 142/142 [==============================] - 24s 169ms/step - loss: 0.2211 - accuracy: 0.9429 - val_loss: 0.4274 - val_accuracy: 0.8390
# Epoch 87/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.9445
# Epoch 87: val_loss improved from 0.42441 to 0.42310, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 188ms/step - loss: 0.2195 - accuracy: 0.9445 - val_loss: 0.4231 - val_accuracy: 0.8482
# Epoch 88/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2178 - accuracy: 0.9440
# Epoch 88: val_loss improved from 0.42310 to 0.42232, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 192ms/step - loss: 0.2178 - accuracy: 0.9440 - val_loss: 0.4223 - val_accuracy: 0.8451
# Epoch 89/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2154 - accuracy: 0.9449
# Epoch 89: val_loss improved from 0.42232 to 0.42220, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 190ms/step - loss: 0.2154 - accuracy: 0.9449 - val_loss: 0.4222 - val_accuracy: 0.8436
# Epoch 90/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2133 - accuracy: 0.9456
# Epoch 90: val_loss did not improve from 0.42220
# 142/142 [==============================] - 25s 176ms/step - loss: 0.2133 - accuracy: 0.9456 - val_loss: 0.4240 - val_accuracy: 0.8466
# Epoch 91/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9467
# Epoch 91: val_loss improved from 0.42220 to 0.41848, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 27s 188ms/step - loss: 0.2112 - accuracy: 0.9467 - val_loss: 0.4185 - val_accuracy: 0.8451
# Epoch 92/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9496
# Epoch 92: val_loss did not improve from 0.41848
# 142/142 [==============================] - 26s 180ms/step - loss: 0.2086 - accuracy: 0.9496 - val_loss: 0.4190 - val_accuracy: 0.8482
# Epoch 93/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.9500
# Epoch 93: val_loss improved from 0.41848 to 0.41699, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 185ms/step - loss: 0.2065 - accuracy: 0.9500 - val_loss: 0.4170 - val_accuracy: 0.8528
# Epoch 94/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2043 - accuracy: 0.9487
# Epoch 94: val_loss did not improve from 0.41699
# 142/142 [==============================] - 26s 181ms/step - loss: 0.2043 - accuracy: 0.9487 - val_loss: 0.4233 - val_accuracy: 0.8482
# Epoch 95/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.9496
# Epoch 95: val_loss improved from 0.41699 to 0.41599, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 25s 179ms/step - loss: 0.2026 - accuracy: 0.9496 - val_loss: 0.4160 - val_accuracy: 0.8482
# Epoch 96/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2004 - accuracy: 0.9504
# Epoch 96: val_loss improved from 0.41599 to 0.41384, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_gap_clahe.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.2004 - accuracy: 0.9504 - val_loss: 0.4138 - val_accuracy: 0.8482
# Epoch 97/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9524
# Epoch 97: val_loss did not improve from 0.41384
# 142/142 [==============================] - 27s 188ms/step - loss: 0.1989 - accuracy: 0.9524 - val_loss: 0.4148 - val_accuracy: 0.8451
# Epoch 98/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1964 - accuracy: 0.9546
# Epoch 98: val_loss did not improve from 0.41384
# 142/142 [==============================] - 25s 173ms/step - loss: 0.1964 - accuracy: 0.9546 - val_loss: 0.4153 - val_accuracy: 0.8482
# Epoch 99/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1951 - accuracy: 0.9533
# Epoch 99: val_loss did not improve from 0.41384
# 142/142 [==============================] - 25s 173ms/step - loss: 0.1951 - accuracy: 0.9533 - val_loss: 0.4153 - val_accuracy: 0.8482
# Epoch 100/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9531
# Epoch 100: val_loss did not improve from 0.41384
# 142/142 [==============================] - 25s 177ms/step - loss: 0.1930 - accuracy: 0.9531 - val_loss: 0.4192 - val_accuracy: 0.8497
# 21/21 [==============================] - 5s 165ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.9102    0.8216    0.8636       185
# meningioma_tumor     0.7561    0.8289    0.7908       187
#         no_tumor     0.8679    0.9200    0.8932       100
#  pituitary_tumor     0.9253    0.8944    0.9096       180
#
#         accuracy                         0.8589       652
#        macro avg     0.8649    0.8662    0.8643       652
#     weighted avg     0.8637    0.8589    0.8600       652

# %% [markdown]
# ## Experiment 4
# Use two dense layer of 256 units.

# %%
model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(4, activation='softmax'))

# freeze the layers of the pretrained model
for layer in base_model.layers:
    layer.trainable = False

# compile the model
compile_model(model)

# run the model
run_model(model, 'InceptionV3', "InceptionV3_256_256_clahe")

# evaluate model
evaluate_model(model,test_generator, 'InceptionV3_256_256_clahe', "InceptionV3")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 256)               524544
#
#  dense_7 (Dense)             (None, 256)               65792
#
#  dense_8 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 22,394,148
# Trainable params: 591,364
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 0.7783 - accuracy: 0.6865
# Epoch 1: val_loss improved from inf to 0.63689, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_256_256_clahe.h5
# 142/142 [==============================] - 32s 188ms/step - loss: 0.7783 - accuracy: 0.6865 - val_loss: 0.6369 - val_accuracy: 0.7469
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4761 - accuracy: 0.8122
# Epoch 2: val_loss improved from 0.63689 to 0.49431, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_256_256_clahe.h5
# 142/142 [==============================] - 26s 184ms/step - loss: 0.4761 - accuracy: 0.8122 - val_loss: 0.4943 - val_accuracy: 0.8190
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8611
# Epoch 3: val_loss did not improve from 0.49431
# 142/142 [==============================] - 25s 175ms/step - loss: 0.3677 - accuracy: 0.8611 - val_loss: 0.5501 - val_accuracy: 0.7914
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3384 - accuracy: 0.8748
# Epoch 4: val_loss did not improve from 0.49431
# 142/142 [==============================] - 25s 178ms/step - loss: 0.3384 - accuracy: 0.8748 - val_loss: 0.5273 - val_accuracy: 0.8160
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.8931
# Epoch 5: val_loss did not improve from 0.49431
# 142/142 [==============================] - 24s 166ms/step - loss: 0.2838 - accuracy: 0.8931 - val_loss: 0.5100 - val_accuracy: 0.8344
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.9153
# Epoch 6: val_loss improved from 0.49431 to 0.48051, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_256_256_clahe.h5
# 142/142 [==============================] - 26s 182ms/step - loss: 0.2223 - accuracy: 0.9153 - val_loss: 0.4805 - val_accuracy: 0.8298
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9325
# Epoch 7: val_loss improved from 0.48051 to 0.40849, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_256_256_clahe.h5
# 142/142 [==============================] - 26s 183ms/step - loss: 0.1892 - accuracy: 0.9325 - val_loss: 0.4085 - val_accuracy: 0.8589
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9414
# Epoch 8: val_loss did not improve from 0.40849
# 142/142 [==============================] - 25s 174ms/step - loss: 0.1543 - accuracy: 0.9414 - val_loss: 0.5172 - val_accuracy: 0.8528
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9485
# Epoch 9: val_loss did not improve from 0.40849
# 142/142 [==============================] - 26s 183ms/step - loss: 0.1372 - accuracy: 0.9485 - val_loss: 0.6177 - val_accuracy: 0.8098
# Epoch 10/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1039 - accuracy: 0.9631
# Epoch 10: val_loss did not improve from 0.40849
# 142/142 [==============================] - 26s 182ms/step - loss: 0.1039 - accuracy: 0.9631 - val_loss: 0.5341 - val_accuracy: 0.8282
# Epoch 11/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9726
# Epoch 11: val_loss did not improve from 0.40849
# 142/142 [==============================] - 24s 167ms/step - loss: 0.0778 - accuracy: 0.9726 - val_loss: 0.6012 - val_accuracy: 0.8390
# Epoch 12/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9626
# Epoch 12: val_loss did not improve from 0.40849
# 142/142 [==============================] - 24s 172ms/step - loss: 0.1026 - accuracy: 0.9626 - val_loss: 0.6304 - val_accuracy: 0.8390
# 21/21 [==============================] - 5s 167ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.7664    0.8865    0.8221       185
# meningioma_tumor     0.8768    0.6471    0.7446       187
#         no_tumor     0.9375    0.9000    0.9184       100
#  pituitary_tumor     0.8627    0.9778    0.9167       180
#
#         accuracy                         0.8451       652
#        macro avg     0.8609    0.8528    0.8504       652
#     weighted avg     0.8509    0.8451    0.8407       652

# %% [markdown]
# ## Experiment 5
# Add complexity to the model with more dense layer and dropout.

# %%
model = Sequential()
model.add(base_model)
model.add(Flatten())
# model.add(Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01), bias_regularizer=tf.keras.regularizers.l2(0.01))
model.add(Dense(512, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dense(4, activation='softmax'))

# freeze the layers of the pretrained model
for layer in base_model.layers:
    layer.trainable = False

# compile the model
compile_model(model)

# run the model
run_model(model, 'InceptionV3', "InceptionV3_512_512_drop_clahe")

# evaluate model
evaluate_model(model,test_generator, 'InceptionV3_512_512_drop_clahe', "InceptionV3")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_2 (Flatten)         (None, 51200)             0
#
#  dense_9 (Dense)             (None, 512)               26214912
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_11 (Dense)            (None, 512)               262656
#
#  dense_12 (Dense)            (None, 4)                 2052
#
# =================================================================
# Total params: 48,545,060
# Trainable params: 26,742,276
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 2.6168 - accuracy: 0.5876
# Epoch 1: val_loss improved from inf to 0.77689, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_512_512_drop_clahe.h5
# 142/142 [==============================] - 37s 225ms/step - loss: 2.6168 - accuracy: 0.5876 - val_loss: 0.7769 - val_accuracy: 0.6933
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5579 - accuracy: 0.7967
# Epoch 2: val_loss improved from 0.77689 to 0.47273, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_512_512_drop_clahe.h5
# 142/142 [==============================] - 37s 259ms/step - loss: 0.5579 - accuracy: 0.7967 - val_loss: 0.4727 - val_accuracy: 0.8206
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3549 - accuracy: 0.8701
# Epoch 3: val_loss did not improve from 0.47273
# 142/142 [==============================] - 27s 191ms/step - loss: 0.3549 - accuracy: 0.8701 - val_loss: 0.5098 - val_accuracy: 0.8206
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2441 - accuracy: 0.9104
# Epoch 4: val_loss improved from 0.47273 to 0.42308, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_512_512_drop_clahe.h5
# 142/142 [==============================] - 33s 229ms/step - loss: 0.2441 - accuracy: 0.9104 - val_loss: 0.4231 - val_accuracy: 0.8528
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1966 - accuracy: 0.9308
# Epoch 5: val_loss did not improve from 0.42308
# 142/142 [==============================] - 26s 181ms/step - loss: 0.1966 - accuracy: 0.9308 - val_loss: 0.4591 - val_accuracy: 0.8451
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9542
# Epoch 6: val_loss did not improve from 0.42308
# 142/142 [==============================] - 24s 171ms/step - loss: 0.1252 - accuracy: 0.9542 - val_loss: 0.5944 - val_accuracy: 0.8512
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1366 - accuracy: 0.9498
# Epoch 7: val_loss did not improve from 0.42308
# 142/142 [==============================] - 24s 172ms/step - loss: 0.1366 - accuracy: 0.9498 - val_loss: 0.4799 - val_accuracy: 0.8804
# Epoch 8/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9765
# Epoch 8: val_loss did not improve from 0.42308
# 142/142 [==============================] - 25s 174ms/step - loss: 0.0729 - accuracy: 0.9765 - val_loss: 0.6165 - val_accuracy: 0.8589
# Epoch 9/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9737
# Epoch 9: val_loss did not improve from 0.42308
# 142/142 [==============================] - 25s 173ms/step - loss: 0.0858 - accuracy: 0.9737 - val_loss: 1.0763 - val_accuracy: 0.7653
# 21/21 [==============================] - 5s 159ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.6641    0.9189    0.7710       185
# meningioma_tumor     0.8069    0.6257    0.7048       187
#         no_tumor     0.7787    0.9500    0.8559       100
#  pituitary_tumor     0.9690    0.6944    0.8091       180
#
#         accuracy                         0.7776       652
#        macro avg     0.8047    0.7973    0.7852       652
#     weighted avg     0.8068    0.7776    0.7755       652

# %% [markdown]
# # Fine Tuning

# %% [markdown]
# Previous feature extraction experiments have not led to remarkable results. The first experiment turns out to be the most satisfying of all, let's take this as a starting point to proceed with a fine tuning experiment.

# %% [markdown]
# ## Experiment 1
# Try to increase performance unfreezing last block of InceptionV3

# %%
model_name = "InceptionV3_128_lr_clahe"

model = tf.keras.models.load_model(models_path + "/InceptionV3/"  + model_name + ".h5")

model.trainable = True
base_model = model.get_layer('inception_v3')

set_trainable = False
for layer in base_model.layers:
    if layer.name == 'mixed9':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(model)

run_model(model, 'InceptionV3', "InceptionV3_128_lr_fine_tuning_exp1_clahe")

evaluate_model(model, test_generator, "InceptionV3_128_lr_fine_tuning_exp1_clahe", "InceptionV3")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_2 (Dense)             (None, 128)               6553728
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 28,357,028
# Trainable params: 12,627,780
# Non-trainable params: 15,729,248
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.4187 - accuracy: 0.7588
# Epoch 1: val_loss improved from inf to 0.56820, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_fine_tuning_exp1_clahe.h5
# 142/142 [==============================] - 40s 205ms/step - loss: 1.4187 - accuracy: 0.7588 - val_loss: 0.5682 - val_accuracy: 0.8190
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2089 - accuracy: 0.9250
# Epoch 2: val_loss improved from 0.56820 to 0.40274, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_fine_tuning_exp1_clahe.h5
# 142/142 [==============================] - 30s 209ms/step - loss: 0.2089 - accuracy: 0.9250 - val_loss: 0.4027 - val_accuracy: 0.8773
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0818 - accuracy: 0.9741
# Epoch 3: val_loss did not improve from 0.40274
# 142/142 [==============================] - 26s 180ms/step - loss: 0.0818 - accuracy: 0.9741 - val_loss: 0.5523 - val_accuracy: 0.8666
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9788
# Epoch 4: val_loss did not improve from 0.40274
# 142/142 [==============================] - 26s 183ms/step - loss: 0.0712 - accuracy: 0.9788 - val_loss: 0.4906 - val_accuracy: 0.8926
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9801
# Epoch 5: val_loss did not improve from 0.40274
# 142/142 [==============================] - 24s 170ms/step - loss: 0.0589 - accuracy: 0.9801 - val_loss: 0.5510 - val_accuracy: 0.8911
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9757
# Epoch 6: val_loss did not improve from 0.40274
# 142/142 [==============================] - 25s 174ms/step - loss: 0.0703 - accuracy: 0.9757 - val_loss: 0.5789 - val_accuracy: 0.8911
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9836
# Epoch 7: val_loss did not improve from 0.40274
# 142/142 [==============================] - 27s 187ms/step - loss: 0.0495 - accuracy: 0.9836 - val_loss: 0.5241 - val_accuracy: 0.8804
# 21/21 [==============================] - 4s 140ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.9157    0.8811    0.8981       185
# meningioma_tumor     0.8622    0.9037    0.8825       187
#         no_tumor     0.9773    0.8600    0.9149       100
#  pituitary_tumor     0.9316    0.9833    0.9568       180
#
#         accuracy                         0.9126       652
#        macro avg     0.9217    0.9070    0.9131       652
#     weighted avg     0.9142    0.9126    0.9124       652

# %% [markdown]
# ## Experiment 2
# We have a good results in validation accuracy but the validation loss is still high, try to unfreeze other layer in the base model

# %%
model_name = "InceptionV3_128_lr_clahe"

model = tf.keras.models.load_model(models_path + "/InceptionV3/"  + model_name + ".h5")

model.trainable = True
base_model = model.get_layer('inception_v3')

set_trainable = False
for layer in base_model.layers:
    if layer.name == 'mixed8':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(model)

run_model(model, 'InceptionV3', "InceptionV3_128_lr_fine_tuning_exp2_clahe")

evaluate_model(model, test_generator, "InceptionV3_128_lr_fine_tuning_exp2_clahe", "InceptionV3")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_2 (Dense)             (None, 128)               6553728
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 28,357,028
# Trainable params: 17,669,124
# Non-trainable params: 10,687,904
# _________________________________________________________________
# Epoch 1/100
# 142/142 [==============================] - ETA: 0s - loss: 1.1573 - accuracy: 0.7827
# Epoch 1: val_loss improved from inf to 0.50033, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_fine_tuning_exp2_clahe.h5
# 142/142 [==============================] - 41s 205ms/step - loss: 1.1573 - accuracy: 0.7827 - val_loss: 0.5003 - val_accuracy: 0.8543
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2265 - accuracy: 0.9219
# Epoch 2: val_loss improved from 0.50033 to 0.37397, saving model to /content/drive/MyDrive/DiDonato_Giorgi/Models/CLAHE/InceptionV3/InceptionV3_128_lr_fine_tuning_exp2_clahe.h5
# 142/142 [==============================] - 36s 257ms/step - loss: 0.2265 - accuracy: 0.9219 - val_loss: 0.3740 - val_accuracy: 0.8788
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9504
# Epoch 3: val_loss did not improve from 0.37397
# 142/142 [==============================] - 26s 183ms/step - loss: 0.1434 - accuracy: 0.9504 - val_loss: 0.8575 - val_accuracy: 0.7960
# Epoch 4/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9628
# Epoch 4: val_loss did not improve from 0.37397
# 142/142 [==============================] - 28s 194ms/step - loss: 0.1141 - accuracy: 0.9628 - val_loss: 0.5843 - val_accuracy: 0.8650
# Epoch 5/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1074 - accuracy: 0.9648
# Epoch 5: val_loss did not improve from 0.37397
# 142/142 [==============================] - 26s 180ms/step - loss: 0.1074 - accuracy: 0.9648 - val_loss: 0.3879 - val_accuracy: 0.9172
# Epoch 6/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9843
# Epoch 6: val_loss did not improve from 0.37397
# 142/142 [==============================] - 26s 181ms/step - loss: 0.0423 - accuracy: 0.9843 - val_loss: 0.3796 - val_accuracy: 0.9049
# Epoch 7/100
# 142/142 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9770
# Epoch 7: val_loss did not improve from 0.37397
# 142/142 [==============================] - 25s 178ms/step - loss: 0.0735 - accuracy: 0.9770 - val_loss: 0.4362 - val_accuracy: 0.9064
# 21/21 [==============================] - 4s 135ms/step
# Classification report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor     0.8286    0.9405    0.8810       185
# meningioma_tumor     0.9075    0.8396    0.8722       187
#         no_tumor     0.9886    0.8700    0.9255       100
#  pituitary_tumor     0.9558    0.9611    0.9584       180
#
#         accuracy                         0.9064       652
#        macro avg     0.9201    0.9028    0.9093       652
#     weighted avg     0.9109    0.9064    0.9067       652
